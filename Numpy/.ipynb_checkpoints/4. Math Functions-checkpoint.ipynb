# %%
import numpy as np

# %%
arr = np.random.rand(5,5)
arr
# Out:
# array([[0.32309264, 0.86853208, 0.32953244, 0.9522127 , 0.6242202 ],
#        [0.22979966, 0.77295632, 0.58720708, 0.94627397, 0.87912777],
#        [0.04273737, 0.34010481, 0.99599655, 0.41355811, 0.1477688 ],
#        [0.79720384, 0.078284  , 0.99072101, 0.53912023, 0.36603662],
#        [0.50579245, 0.63380049, 0.33688458, 0.08527731, 0.51870877]])

# %% [markdown]
# ### element-wise addition, subtraction, multiplication and division

# %%
print(arr + 10)
print()
print(arr - 10)
print()
print(arr * 10)
print()
print(arr / 10)
# Out:
# [[10.32309264 10.86853208 10.32953244 10.9522127  10.6242202 ]
#  [10.22979966 10.77295632 10.58720708 10.94627397 10.87912777]
#  [10.04273737 10.34010481 10.99599655 10.41355811 10.1477688 ]
#  [10.79720384 10.078284   10.99072101 10.53912023 10.36603662]
#  [10.50579245 10.63380049 10.33688458 10.08527731 10.51870877]]
#
# [[-9.67690736 -9.13146792 -9.67046756 -9.0477873  -9.3757798 ]
#  [-9.77020034 -9.22704368 -9.41279292 -9.05372603 -9.12087223]
#  [-9.95726263 -9.65989519 -9.00400345 -9.58644189 -9.8522312 ]
#  [-9.20279616 -9.921716   -9.00927899 -9.46087977 -9.63396338]
#  [-9.49420755 -9.36619951 -9.66311542 -9.91472269 -9.48129123]]
#
# [[3.23092636 8.68532079 3.29532443 9.52212704 6.24220196]
#  [2.29799655 7.72956322 5.87207079 9.46273971 8.79127772]
#  [0.42737371 3.40104808 9.95996549 4.13558112 1.47768803]
#  [7.97203845 0.78283998 9.90721012 5.39120234 3.66036618]
#  [5.05792445 6.33800488 3.36884577 0.85277306 5.1870877 ]]
#
# [[0.03230926 0.08685321 0.03295324 0.09522127 0.06242202]
#  [0.02297997 0.07729563 0.05872071 0.0946274  0.08791278]
#  [0.00427374 0.03401048 0.09959965 0.04135581 0.01477688]
#  [0.07972038 0.0078284  0.0990721  0.05391202 0.03660366]
#  [0.05057924 0.06338005 0.03368846 0.00852773 0.05187088]]

# %%
# the above operations can be performed using numpy built-in functions
# which can save memory as the output can be stored in the original array rather than assigning new memory
arr1 = np.array([1,2,3])
x = np.add(arr1, [8,9,10], out=arr1)
print(arr1)

np.subtract(arr1, [2,1,12], out=arr1)
print(arr1)

np.multiply(arr1, [1,2,3], out=arr1)
print(arr1)
# Out:
# [ 9 11 13]
# [ 7 10  1]
# [ 7 20  3]

# %% [markdown]
# ### element-wise exponentiation

# %%
print(np.exp(arr))
# Out:
# [[1.38139331 2.38340963 1.39031792 2.5914374  1.86678966]
#  [1.25834788 2.16616067 1.79895705 2.57609316 2.40879777]
#  [1.04366376 1.40509485 2.70742107 1.51218876 1.15924485]
#  [2.21932666 1.08142974 2.69317558 1.71449784 1.44200805]
#  [1.65829911 1.88475999 1.40057739 1.08901902 1.67985717]]

# %% [markdown]
# ### element-wise logorithm

# %%
# natural log
print(np.log(arr))
# Out:
# [[-1.1298162  -0.14095076 -1.11008047 -0.04896684 -0.47125209]
#  [-1.47054741 -0.25753274 -0.53237775 -0.05522314 -0.12882503]
#  [-3.15268154 -1.07850145 -0.00401149 -0.88295724 -1.91210637]
#  [-0.22664487 -2.54741206 -0.00932231 -0.61781666 -1.0050219 ]
#  [-0.68162888 -0.45602106 -1.08801491 -2.46184691 -0.65641269]]

# %%
# base 2
print(np.log2(arr))
# Out:
# [[-1.62998023 -0.20334896 -1.60150759 -0.07064422 -0.67987306]
#  [-2.12155146 -0.3715412  -0.76805873 -0.07967015 -0.18585523]
#  [-4.54835802 -1.55594869 -0.00578735 -1.27383803 -2.75858637]
#  [-0.32697943 -3.67513874 -0.01344924 -0.89132104 -1.44994011]
#  [-0.98338261 -0.65789932 -1.56967372 -3.55169432 -0.94700333]]

# %%
# base 10
print(np.log10(arr))
# Out:
# [[-0.49067294 -0.06121414 -0.48210182 -0.02126603 -0.20466218]
#  [-0.63865063 -0.11184505 -0.23120872 -0.02398311 -0.055948  ]
#  [-1.3691922  -0.46838723 -0.00174217 -0.38346346 -0.83041724]
#  [-0.09843062 -1.106327   -0.00404863 -0.26831437 -0.43647547]
#  [-0.29602766 -0.19804743 -0.47251887 -1.06916653 -0.28507641]]

# %% [markdown]
# ### element-wise square root

# %%
print(np.sqrt(arr))
# Out:
# [[0.56841238 0.93195068 0.57404916 0.97581387 0.79007607]
#  [0.47937423 0.87917935 0.76629438 0.97276614 0.93761814]
#  [0.20673019 0.58318505 0.99799627 0.64308484 0.38440708]
#  [0.89286272 0.27979278 0.99534969 0.73424807 0.6050096 ]
#  [0.71119086 0.79611588 0.58041759 0.29202278 0.72021439]]

# %% [markdown]
# ### element-wise sine and cosine

# %%
print(np.sin(arr))
# Out:
# [[0.31750069 0.76338156 0.32360066 0.8147006  0.5844647 ]
#  [0.22778245 0.69825457 0.5540381  0.8112425  0.77018284]
#  [0.04272436 0.3335859  0.83930117 0.40187002 0.14723162]
#  [0.71540519 0.07820406 0.83642137 0.51338121 0.35791743]
#  [0.48450082 0.59221139 0.3305484  0.08517398 0.49575917]]

# %%
print(np.cos(arr))
# Out:
# [[0.94825804 0.64594783 0.94619375 0.57988182 0.81141913]
#  [0.97371205 0.71584954 0.83249131 0.58470985 0.63782316]
#  [0.9990869  0.94271971 0.54366675 0.91569672 0.98910204]
#  [0.69870982 0.99693737 0.54808693 0.85816067 0.93375324]
#  [0.87479081 0.80578264 0.94378904 0.99636609 0.86846004]]

# %% [markdown]
# ### sum along a specified axis

# %%
# sum along the row
print(np.sum(arr, axis=0))
# Out:
# [1.89862595 2.6936777  3.24034166 2.93644233 2.53586216]

# %%
# sum along the column
print(np.sum(arr, axis=1))
# Out:
# [3.09759006 3.4153648  1.94016564 2.77136571 2.08046359]

# %% [markdown]
# ### compute the min and max along a specified axis

# %%
# calculate min along the row
print(np.min(arr, axis=0))
# Out:
# [0.04273737 0.078284   0.32953244 0.08527731 0.1477688 ]

# %%
# calculate max along the column
print(np.max(arr, axis=1))
# Out:
# [0.9522127  0.94627397 0.99599655 0.99072101 0.63380049]

# %%
# if axis not specified, calculate the max/min value of all elements
print(np.max(arr))
print(np.min(arr))
# Out:
# 0.995996548838682
# 0.0427373710664789

# %% [markdown]
# ### compute the indices of the min and max along a specified axis

# %%
arr
# Out:
# array([[0.32309264, 0.86853208, 0.32953244, 0.9522127 , 0.6242202 ],
#        [0.22979966, 0.77295632, 0.58720708, 0.94627397, 0.87912777],
#        [0.04273737, 0.34010481, 0.99599655, 0.41355811, 0.1477688 ],
#        [0.79720384, 0.078284  , 0.99072101, 0.53912023, 0.36603662],
#        [0.50579245, 0.63380049, 0.33688458, 0.08527731, 0.51870877]])

# %%
# along the row
print(np.argmin(arr, axis=0))
print(np.argmax(arr, axis=0))
# Out:
# [2 3 0 4 2]
# [3 0 2 0 1]

# %%
# along the column
print(np.argmin(arr, axis=1))
print(np.argmax(arr, axis=1))
# Out:
# [0 0 0 1 3]
# [3 3 2 2 1]

# %%
# if axis not specified, return the index of the flattened array
print(np.argmin(arr))
print(np.argmax(arr))
# Out:
# 10
# 12

# %% [markdown]
# ### compute element-wise min and max of two arrays

# %%
arr1 = np.array([1, 3, 5, 7, 9])
arr2 = np.array([0, 4, 3, 8, 7])
print(np.maximum(arr1, arr2))
print()
print(np.minimum(arr1, arr2))
# Out:
# [1 4 5 8 9]
#
# [0 3 3 7 7]

# %% [markdown]
# ### split fractional and integral parts of a floating-point array

# %%
print(20 / 3)
x = 20/3
x = str(x)
x = int(x[2:])
print(x)
print (20 // 3)
# Out:
# 6.666666666666667
# 666666666666667
# 6

# %%
y= ((20/3)-(20 // 3)) 
x = (len(str((20/3)-(20 // 3)))-2)
print(int((10**x) * y))
# Out:
# 666666666666667

# %%
20 % 3
# Out:
# 2

# %%
arr1 = np.random.rand(10) * 10

print(arr1)
print()
re, intg = np.modf(arr1)
print('fractional: ', re)
print('integral: ', intg)
# Out:
# [1.90116681 7.26907877 7.11916425 0.05776791 8.59822926 5.42207592
#  2.01326083 1.43702047 0.02199224 1.1024508 ]
#
# fractional:  [0.90116681 0.26907877 0.11916425 0.05776791 0.59822926 0.42207592
#  0.01326083 0.43702047 0.02199224 0.1024508 ]
# integral:  [1. 7. 7. 0. 8. 5. 2. 1. 0. 1.]

# %%
newarr = np.array([1.23,])
re , intg  = np.modf(newarr)

# rounding the number to get the accurate reuslt
fraction = round(float(re), 2)
integer = int(intg)
print(fraction)
print(integer)
# Out:
# 0.23
# 1

# %% [markdown]
# ### compute the mean

# %%
# compute the overall mean
print(np.mean(arr))
# Out:
# 0.5321979918759767

# %%
# compute the mean along the row
print(np.mean(arr, axis=0))
# Out:
# [0.37972519 0.53873554 0.64806833 0.58728847 0.50717243]

# %%
# compute the mean along the column
print(np.mean(arr, axis=1))
# Out:
# [0.61951801 0.68307296 0.38803313 0.55427314 0.41609272]

# %% [markdown]
# ### compute the median

# %%
# compute the overall median
x = [1,2,4,6,7,8,9,12, 20]
print(np.median(x))
# Out:
# 7.0

# %%
# compute the median along the row
print(np.median(arr, axis=0))
# Out:
# [0.32309264 0.63380049 0.58720708 0.53912023 0.51870877]

# %%
# compute the median along the column
print(np.median(arr, axis=1))
# Out:
# [0.6242202  0.77295632 0.34010481 0.53912023 0.50579245]

# %% [markdown]
# ### compute the percentile

# %%
arr1 = np.random.rand(100)
# compute 5, 65, and 95 percentiles of the array
print(np.percentile(arr1, [5, 65, 95]))
# Out:
# [0.06135086 0.65120061 0.93212193]

# %% [markdown]
# ### compute the standard deviation & variance

# %%
# compute the overall standard deviation
print(np.std(arr))
# Out:
# 0.29958306834042564

# %%
# compute the standard deviation along the row
print(np.std(arr, axis=0))
# Out:
# [0.21938443 0.19539073 0.25107324 0.27967879 0.17020155]

# %%
# compute the standard deviation along the column
print(np.std(arr, axis=1))
# Out:
# [0.30641368 0.17126526 0.29126051 0.24542809 0.23354205]

# %%
# compute the overall variance
print(np.var(arr))
# Out:
# 0.08975001483626414

# %%
# compute the variance along the row
print(np.var(arr, axis=0))
# Out:
# [0.06588542 0.08482645 0.08809389 0.10931158 0.06025487]

# %%
# compute the variance along the column
print(np.var(arr, axis=1))
# Out:
# [0.0689351  0.06608765 0.10990486 0.10234607 0.03633711]

# %% [markdown]
# ### compute the covariance & correlation

# %%
arr = np.random.rand(5,8)
arr
# Out:
# array([[0.66432128, 0.47823909, 0.08649294, 0.28509912, 0.39145114,
#         0.66624351, 0.49319099, 0.64238111],
#        [0.57039151, 0.6067183 , 0.14064614, 0.656572  , 0.13000909,
#         0.50169827, 0.73048919, 0.93561593],
#        [0.52900441, 0.30406697, 0.47701092, 0.18667546, 0.54288467,
#         0.48607062, 0.97339748, 0.65880004],
#        [0.29466158, 0.58411079, 0.12063946, 0.79667082, 0.69542437,
#         0.33337981, 0.5642767 , 0.40108484],
#        [0.79489881, 0.6391955 , 0.12314094, 0.23910298, 0.38625675,
#         0.39916181, 0.89932551, 0.93349019]])

# %%
print(np.cov(arr))
# Out:
# [[ 0.04195479  0.03357769  0.01486583 -0.00193764  0.04672526]
#  [ 0.03357769  0.07721698  0.01390884  0.0119386   0.06269644]
#  [ 0.01486583  0.01390884  0.05516722 -0.01101519  0.04541586]
#  [-0.00193764  0.0119386  -0.01101519  0.05079081  0.0007072 ]
#  [ 0.04672526  0.06269644  0.04541586  0.0007072   0.09506105]]

# %%
print(np.corrcoef(arr[:,0], arr[:,1]))
# Out:
# [[1.         0.13982631]
#  [0.13982631 1.        ]]

# %% [markdown]
# ### compute cumulative sum & product

# %%
       1 3 5 6 8 9
csum = 1 4 9 15 23 32
cpor = 1 3 15 90 720 ...

# %%
# calculate the cumulative sums along the row
print(np.cumsum(arr, axis=0))
# Out:
# [[0.32309264 0.86853208 0.32953244 0.9522127  0.6242202 ]
#  [0.55289229 1.6414884  0.91673952 1.89848668 1.50334797]
#  [0.59562966 1.98159321 1.91273607 2.31204479 1.65111677]
#  [1.39283351 2.05987721 2.90345708 2.85116502 2.01715339]
#  [1.89862595 2.6936777  3.24034166 2.93644233 2.53586216]]

# %%
# calculate the cumulative sums along the column
print(np.cumsum(arr, axis=1))
# Out:
# [[0.66432128 1.14256036 1.2290533  1.51415242 1.90560356 2.57184707
#   3.06503806 3.70741917]
#  [0.57039151 1.1771098  1.31775595 1.97432795 2.10433704 2.60603532
#   3.3365245  4.27214043]
#  [0.52900441 0.83307138 1.3100823  1.49675776 2.03964242 2.52571304
#   3.49911052 4.15791056]
#  [0.29466158 0.87877237 0.99941183 1.79608265 2.49150702 2.82488683
#   3.38916354 3.79024838]
#  [0.79489881 1.43409431 1.55723525 1.79633823 2.18259498 2.5817568
#   3.48108231 4.4145725 ]]

# %%
# calculate the cumulative product along the row
print(np.cumprod(arr, axis=0))
# Out:
# [[2.26307776e-01 7.67801004e-01 5.82881038e-01 9.12129639e-01
#   1.68660858e-01 7.12257767e-01 7.59926931e-01 4.30365348e-01]
#  [8.24710772e-02 4.95872414e-01 3.99554306e-01 4.38450855e-01
#   1.13874845e-03 2.70457451e-01 6.08731528e-01 9.01329430e-02]
#  [2.29626035e-02 1.78423193e-01 1.49709241e-01 2.73509837e-01
#   6.01584614e-04 5.35311066e-02 1.86145622e-01 8.15719823e-02]
#  [1.99861456e-02 1.10243142e-01 9.94219814e-02 7.71824276e-02
#   1.17917453e-04 4.08128596e-02 1.39430701e-01 2.30694183e-02]
#  [1.98498821e-02 6.99678041e-02 5.39769526e-02 6.28059168e-02
#   7.45045544e-05 2.16162260e-02 1.80866051e-02 2.16579420e-02]]

# %%
# calculate the cumulative product along the column
print(np.cumprod(arr, axis=1))
# Out:
# [[2.26307776e-01 1.73759338e-01 1.01281023e-01 9.23814230e-02
#   1.55811300e-02 1.10977809e-02 8.43350257e-03 3.62948727e-03]
#  [3.64419989e-01 2.35355019e-01 1.61331567e-01 7.75503399e-02
#   5.23597062e-04 1.98819491e-04 1.59262276e-04 3.33548640e-05]
#  [2.78432201e-01 1.00184566e-01 3.75382145e-02 2.34166972e-02
#   1.23707081e-02 2.44850971e-03 7.48736253e-04 6.77620172e-04]
#  [8.70378028e-01 5.37784391e-01 3.57142882e-01 1.00783047e-01
#   1.97546278e-02 1.50612027e-02 1.12814582e-02 3.19051555e-03]
#  [9.93182100e-01 6.30340985e-01 3.42216932e-01 2.78473337e-01
#   1.75949628e-01 9.31904051e-02 1.20884285e-02 1.13488117e-02]]

# %% [markdown]
# ### element-wise comparison

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([5,4,3,2,1])

# %%
# return an array of bools
print(arr1 == arr2)    
print(arr1 < 3)
# Out:
# [False False  True False False]
# [ True  True False False False]
