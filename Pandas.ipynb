# %% [markdown]
# <center> <h1> Pandas </h1> </center>
#
# ### Pandas : Data Preprocessing
# Also check : Pyspark, Dask, Mito, Polars, modin, Vaex, YoloPandas, PandasAI, pandas-profiling, vanna, sweetviz, autoviz , auto clean

# %% [markdown]
# **Data Scientist**
#
# 1. Server ( Cloud ) : Read/access data from server
# 2. Local : Access file through network, direct access
#
# **Data could be of different types:** <br>
#
# - Sql Database
# - Oracle Database
# - Mongodb ( json objects )
# - Firebase
# - txt
# - log file
# - xls, xlsx
# - csv ( comma seperated values ==> Ahmed, Mohamed, Ali)
# - json ( javascript object notation )
# - Live data ( ex: https://www.worldometers.info/ )
# - pdf
# - word, pptx
#
#
# **Note:** Data must be well documented : https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
#
#
# **Basic Pandas Concepts:**
#
# 1. Read Data
# 2. Explore Data Frame : info, columns, describe, mean, median
# 3. Cleaning: Drop Columns, Deal with duplicates, Rename Columns, deal with dates column
# 4. Deal with missing values ( fillna, drop, replace )
# 5. Univarient, Bivarient, Multivarient Analysis
# 6. Read Data from Different Types
# 7. Concat
# 8. Merge, join
# 9. Group by
# 10. Cross tab
# 11. Pivot / Pivot Table
# 12. Holidays
# 13. Connect to SQL & MongoDB

# %%
import pandas as pd
df = pd.read_csv('data/nyc_weather.csv') # new york whether
df #  Data Frame
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (31, 11)

# %%
df["Sea Level PressureIn"]
# Out:
# 0     30.03
# 1     30.02
# 2     29.86
# 3     30.05
# 4     30.57
# 5     30.50
# 6     30.28
# 7     30.20
# 8     30.16
# 9     29.59
# 10    29.92
# 11    29.85
# 12    29.94
# 13    29.95
# 14    29.82
# 15    29.52
# 16    29.78
# 17    29.83
# 18    30.03
# 19    30.13
# 20    30.15
# 21    30.21
# 22    29.77
# 23    29.92
# 24    30.25
# 25    30.03
# 26    30.03
# 27    29.90
# 28    29.58
# 29    30.01
# 30    29.90
# Name: Sea Level PressureIn, dtype: float64

# %%
df["Sea Level PressureIn"].max()
# Out:
# 30.57

# %%
df["Sea Level PressureIn"] = df["Sea Level PressureIn"].astype("float32")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
x = df.columns.to_list()
print(x)
type(x)
# Out:
# ['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn', 'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees']
# list

# %%
for i in df.Temperature:
    if (i > 30):
        print(i)
# Out:
# 38
# 36
# 40
# 33
# 39
# 39
# 44
# 50
# 33
# 35
# 43
# 47
# 36
# 32
# 31
# 34
# 43
# 41
# 37
# 36
# 34
# 46

# %%
df.loc[0][0] #location
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_69346/732012314.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0] #location
# '1/1/2016'

# %%
df.iloc[0][0] #location
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_69346/3913698342.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0] #location
# '1/1/2016'

# %%
df.iloc[0,0] #location
# Out:
# '1/1/2016'

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52             30.030001
# 1    1/2/2016           36        18        46             30.020000
# 2    1/3/2016           40        21        47             29.860001
# 3    1/4/2016           25         9        44             30.049999
# 4    1/5/2016           20        -3        41             30.570000
# 5    1/6/2016           33         4        35             30.500000
# 6    1/7/2016           39        11        33             30.280001
# 7    1/8/2016           39        29        64             30.200001
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 10  1/11/2016           33         8        37             29.920000
# 11  1/12/2016           35        15        53             29.850000
# 12  1/13/2016           26         4        42             29.940001
# ...

# %%
df.iloc[ 0 , 2 ]
# Out:
# 23

# %%
df.columns[0]
# Out:
# 'EST'

# %%
counter = 0
for i in df.Temperature:
    if (i >= 30):
        counter+=1
counter
# Out:
# 23

# %%
counter = 0 
for i in df.Events: 
    if (i == "Rain"):
        counter+= 1
counter
# Out:
# 4

# %%
# df[ Condition ]
df [ df.Events == "Rain"  ]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77             30.160000
# 9   1/10/2016           50        46        71             29.590000
# 15  1/16/2016           47        37        70             29.520000
# 26  1/27/2016           41        22        45             30.030001
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
len(df [ df.Events == "Rain"  ])
# Out:
# 4

# %%
df [ df.Events == "Rain"  ].shape[0]
# Out:
# 4

# %%
#print(df['Temperature'])
df["EST"][df.Events == "Rain"]
#print(len(df["EST"][df.Events == "Rain"]))
#df[column] [condition]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df[df.Events == "Rain"]["EST"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df["Temperature"][df.Events == "Rain"]
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
df[df.Events == "Rain"]["Temperature"]
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
print(df.DewPoint.dtype)
# Out:
# int64

# %%
print(df.WindSpeedMPH.dtype)
# Out:
# float64

# %%
df["Temperature"][df.Events == "Rain"]
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
print(f"you have : {len(df.columns)} columns" )
# Out:
# you have : 11 columns

# %%
df["EST"][0]
# Out:
# '1/1/2016'

# %%
df['EST'][0:5]
# Out:
# 0    1/1/2016
# 1    1/2/2016
# 2    1/3/2016
# 3    1/4/2016
# 4    1/5/2016
# Name: EST, dtype: object

# %%
df[:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52             30.030001
# 1  1/2/2016           36        18        46             30.020000
# 2  1/3/2016           40        21        47             29.860001
# 3  1/4/2016           25         9        44             30.049999
# 4  1/5/2016           20        -3        41             30.570000
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.iloc[4:10, 3 : 7]
# Out:
#    Humidity  Sea Level PressureIn  VisibilityMiles  WindSpeedMPH
# 4        41             30.570000               10           5.0
# 5        35             30.500000               10           4.0
# 6        33             30.280001               10           2.0
# 7        64             30.200001               10           4.0
# 8        77             30.160000                9           8.0
# 9        71             29.590000                4           NaN

# %%
df.describe() #only works on numerical columns
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992908
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.139999
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
len(df['EST'][ df['Events']!= 'Rain'])
# Out:
# 27

# %%
len(df  [   df['Events']!= 'Rain'   ])
# Out:
# 27

# %%
online_data = pd.read_csv("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")
online_data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Sunny', 'Sunny']
}

# %%
type(weather_data)
# Out:
# dict

# %%
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape # rows, columns = df.shape
# Out:
# (6, 4)

# %%
newdf = df[2:5]
newdf
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny

# %%
newdf = df.iloc[2:5 , 0:-1]
newdf
# Out:
#         day  temperature  windspeed
# 2  1/3/2017           28          2
# 3  1/4/2017           24          7
# 4  1/5/2017           32          4

# %%
# not going to work : newdf = df.loc[2:5, :-2]

# %% [markdown]
# ## <font color='blue'>Rows</font>

# %%
df.head() # print the first 5 rows
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny

# %%
df.head(3) # print the first 3 rows
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.tail(4) # prints the last 4 rows
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.index[df.day ==  "1/4/2017"]
# Out:
# Index([3], dtype='int64')

# %%
index = df.index[df.day ==  "1/4/2017"][0]
print(index)
# Out:
# 3

# %%
startindex = int(df.index[df.day ==  "1/4/2017"][0])
type(startindex)
# Out:
# int

# %%
df[ startindex : startindex + 3 ]
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## <font color='blue'>Columns</font>

# %%
print(df.columns)
columnNames = df.columns.to_list()
print(columnNames)
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')
# ['day', 'temperature', 'windspeed', 'event']

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4    Sunny
# 5    Sunny
# Name: event, dtype: object

# %%
eventlist = df.event.to_list()
eventlist
# Out:
# ['Rain', 'Sunny', 'Snow', 'Snow', 'Sunny', 'Sunny']

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
twodf = df[ ['day','event']  ]
twodf
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017  Sunny
# 5  1/6/2017  Sunny

# %%
del twodf

# %%
twodf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 twodf
#
# NameError: name 'twodf' is not defined

# %% [markdown]
# ## <font>Operations On DataFrame</font>

# %%
print(df.temperature.mean())
print(df['temperature'].std())
# Out:
# 30.333333333333332
# 3.8297084310253524

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
len(df[ df['temperature'] > 30 ])
# Out:
# 4

# %%
df['day'] [ df['temperature'] == df['temperature'].min() ] # Kinda doing SQL in pandas
# Out:
# 3    1/4/2017
# Name: day, dtype: object

# %%
df['day'] [ df['temperature'] == df['temperature'].min() ].tolist()[0]
# Out:
# '1/4/2017'

# %%
# Error 
df['day'] [  df['temperature'].min() ] # Kinda doing SQL in pandas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: 24 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/3777136.py in <module>
#       1 # Error
# ----> 2 df['day'] [  df['temperature'].min() ] # Kinda doing SQL in pandas
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
# ...

# %%
df['day'][df['temperature'] == df['temperature'].min()] # Kinda doing SQL in pandas
# Out:
# 3    1/4/2017
# Name: day, dtype: object

# %%
data = df.temperature.sort_values()
data
# Out:
# 3    24
# 2    28
# 5    31
# 0    32
# 4    32
# 1    35
# Name: temperature, dtype: int64

# %%
data = df.temperature.sort_values(ascending = False)
data
# Out:
# 1    35
# 0    32
# 4    32
# 5    31
# 2    28
# 3    24
# Name: temperature, dtype: int64

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'][3:6].mean()
# Out:
# 29.0

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df['event'].max() # But mean() won't work since data type is string
# Out:
# 'Sunny'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
# get max occuring element

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.event.mode()
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
df.event.value_counts()
# Out:
# event
# Sunny    3
# Snow     2
# Rain     1
# Name: count, dtype: int64

# %%
df.event.value_counts().max()
# Out:
# 3

# %%
df.event.value_counts().idxmax()
# Out:
# 'Sunny'

# %%
df.event.value_counts().index[0]
# Out:
# 'Sunny'

# %%
df.event.value_counts()[0]
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_14080/20397885.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.event.value_counts()[0]
# 3

# %%
print("Max Event : " + df.event.value_counts().index[0] + " and it occured " + str( df.event.value_counts()[0]) + " times" )
# Out:
# Max Event : Sunny and it occured 3 times
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/107983665.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Max Event : " + df.event.value_counts().index[0] + " and it occured " + str( df.event.value_counts()[0]) + " times" )

# %%
df.event.mode()
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# **Google pandas series operations to find out list of all operations**
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %% [markdown]
# ## <font> set_index </font>

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace= True )

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index("day")
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index("day", inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 3)

# %%
df.loc["1/1/2017"]
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.loc["1/1/2017" : "1/4/2017"]
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow

# %%
df.shape
# Out:
# (6, 3)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.set_index("day", inplace= True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4  Sunny
# 5      5  1/6/2017           31          2  Sunny

# %%
df.drop("index", axis = 1 , inplace= True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf = df.copy()
newdf.set_index("day" , inplace=True)

# %%
newdf
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
newdf.reset_index(inplace=True)

# %%
newdf
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf.set_index("event", inplace=True)
newdf
# Out:
#        temperature  windspeed
# event
# Rain            32          6
# Sunny           35          7
# Snow            28          2
# Snow            24          7
# Sunny           32          4
# Sunny           31          2

# %%
newdf [ newdf.event == "Sunny"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_14080/1208918729.py in <module>
# ----> 1 newdf [ newdf.event == "Sunny"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'event'

# %%
newdf.loc["Sunny"]
# Out:
#        temperature  windspeed
# event
# Sunny           35          7
# Sunny           32          4
# Sunny           31          2

# %%
newdf.loc["Snow"]
# Out:
#        temperature  windspeed
# event
# Snow            28          2
# Snow            24          7

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df [ df.event == "Snow"]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow

# %%
import numpy as np 

df["NewData"] = np.arange(1,7) # [ 1,2,3,4,5,6]
df
# Out:
#         day  temperature  windspeed  event  NewData
# 0  1/1/2017           32          6   Rain        1
# 1  1/2/2017           35          7  Sunny        2
# 2  1/3/2017           28          2   Snow        3
# 3  1/4/2017           24          7   Snow        4
# 4  1/5/2017           32          4  Sunny        5
# 5  1/6/2017           31          2  Sunny        6

# %%
mylist = []
for i in df.temperature:
    if i == 32:
        mylist.append(True)
    else:
        mylist.append(False)
df["Check"] = mylist

# %%
df
# Out:
#         day  temperature  windspeed  event  NewData  Check
# 0  1/1/2017           32          6   Rain        1   True
# 1  1/2/2017           35          7  Sunny        2  False
# 2  1/3/2017           28          2   Snow        3  False
# 3  1/4/2017           24          7   Snow        4  False
# 4  1/5/2017           32          4  Sunny        5   True
# 5  1/6/2017           31          2  Sunny        6  False

# %%
df["Names"] = np.array(["Ahmed", "Ali", "Omar" , "Emad" , "Anas" , "Amr" ])
df
# Out:
#         day  temperature  windspeed  event  NewData  Check  Names
# 0  1/1/2017           32          6   Rain        1   True  Ahmed
# 1  1/2/2017           35          7  Sunny        2  False    Ali
# 2  1/3/2017           28          2   Snow        3  False   Omar
# 3  1/4/2017           24          7   Snow        4  False   Emad
# 4  1/5/2017           32          4  Sunny        5   True   Anas
# 5  1/6/2017           31          2  Sunny        6  False    Amr

# %%
df.reset_index(inplace=True)
df.drop("event", inplace=True, axis= 1)
df
# Out:
#    index       day  temperature  windspeed  NewData  Check  Names
# 0      0  1/1/2017           32          6        1   True  Ahmed
# 1      1  1/2/2017           35          7        2  False    Ali
# 2      2  1/3/2017           28          2        3  False   Omar
# 3      3  1/4/2017           24          7        4  False   Emad
# 4      4  1/5/2017           32          4        5   True   Anas
# 5      5  1/6/2017           31          2        6  False    Amr

# %%
df.drop("index", inplace=True, axis = 1)

# %%
df
# Out:
#         day  temperature  windspeed  NewData  Check  Names
# 0  1/1/2017           32          6        1   True  Ahmed
# 1  1/2/2017           35          7        2  False    Ali
# 2  1/3/2017           28          2        3  False   Omar
# 3  1/4/2017           24          7        4  False   Emad
# 4  1/5/2017           32          4        5   True   Anas
# 5  1/6/2017           31          2        6  False    Amr

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#df.reset_index(inplace=True)
df.set_index("temperature", inplace=True)

# %%
df
# Out:
#                   day  windspeed  NewData  Check  Names
# temperature
# 32           1/1/2017          6        1   True  Ahmed
# 35           1/2/2017          7        2  False    Ali
# 28           1/3/2017          2        3  False   Omar
# 24           1/4/2017          7        4  False   Emad
# 32           1/5/2017          4        5   True   Anas
# 31           1/6/2017          2        6  False    Amr

# %%
df.loc[32]
# Out:
#                   day  windspeed  NewData  Check  Names
# temperature
# 32           1/1/2017          6        1   True  Ahmed
# 32           1/5/2017          4        5   True   Anas

# %%
df.head()
# Out:
#                   day  windspeed  NewData  Check  Names
# temperature
# 32           1/1/2017          6        1   True  Ahmed
# 35           1/2/2017          7        2  False    Ali
# 28           1/3/2017          2        3  False   Omar
# 24           1/4/2017          7        4  False   Emad
# 32           1/5/2017          4        5   True   Anas

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Sunny', 'Sunny']
}
df = pd.DataFrame(weather_data)
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Sunny  1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Sunny  1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.to_string()
# Out:
# '            day  temperature  windspeed\nevent                                  \nRain   1/1/2017           32          6\nSunny  1/2/2017           35          7\nSnow   1/3/2017           28          2\nSnow   1/4/2017           24          7\nSunny  1/5/2017           32          4\nSunny  1/6/2017           31          2'

# %%
print(df.to_string())
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Sunny  1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
columns = []
data = dict()

num = int(input("please enter the number of columns: "))
while(num > 0):
    columns.append(input("please enter the column name: "))
    num -=1

for i in columns:
    data[i] = []

rows = int(input("please enter the number of rows: "))
while(rows > 0):
    for i in data:
        value = input(f"please enter the value of {i}: ")
        data[i].append(value)

    rows-=1
dataframe = pd.DataFrame(data)
dataframe
# Out:
# please enter the number of columns: 3
# please enter the column name: name
# please enter the column name: age
# please enter the column name: salary
# please enter the number of rows: 2
# please enter the value of name: Ahmed
# please enter the value of age: 23
# please enter the value of salary: 1334
# please enter the value of name: Emad
# please enter the value of age: 21
# please enter the value of salary: 1000
#     name age salary
# 0  Ahmed  23   1334
# 1   Emad  21   1000

# %%
# make it a function
def create_custom_df(colnum , rownum):
    columns = []
    data = dict()

    num = colnum
    while(num > 0):
        columns.append(input("please enter the column name: "))
        num -=1

    for i in columns:
        data[i] = []

    rows = rownum
    while(rows > 0):
        for i in data:
            value = input(f"please enter the value of {i}: ")
            data[i].append(value)

        rows-=1
    dataframe = pd.DataFrame(data)
    return dataframe

# %%
create_custom_df(2, 3)
# Out:
# please enter the column name: Age
# please enter the column name: Salary
# please enter the value of Age: 23
# please enter the value of Salary: 1000
# please enter the value of Age: 20
# please enter the value of Salary: 3000
# please enter the value of Age: 32
# please enter the value of Salary: 3300
#   Age Salary
# 0  23   1000
# 1  20   3000
# 2  32   3300

# %%
dataframe["name"].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/2155134422.py in <module>
# ----> 1 dataframe["name"].dtype
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.age.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/2813920646.py in <module>
# ----> 1 dataframe.age.dtype
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.age.astype(np.int8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/3664984638.py in <module>
# ----> 1 dataframe.age.astype(np.int8)
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.Age = dataframe.age.astype(np.int16)
dataframe.Age.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/2819945309.py in <module>
# ----> 1 dataframe.Age = dataframe.age.astype(np.int16)
#       2 dataframe.Age.dtype
#
# NameError: name 'dataframe' is not defined

# %% [markdown]
# ### Different Ways Of Creating Dataframe

# %% [markdown]
# ## <font color="green">Using csv</h3></font>

# %%
import pandas as pd
df = pd.read_csv("data/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using excel</h3></font>

# %%
df = pd.read_excel("data/weather_data.xlsx","AbdElRahman") # sheet name
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# **Task : Read all Sheets of excel file using pandas**

# %% [markdown]
# ## <font color="green">Using dictionary</h3></font>

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using tuples list</h3></font>

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using list of dictionaries</h3></font>

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ### Read/Write CSV and Excel Files in Pandas

# %% [markdown]
# ### <font> Read CSV</color>

# %%
import pandas as pd
df = pd.read_csv("data/stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
for col in df.columns:
    print(col , " : " ,  df[col].unique())
# Out:
# tickers  :  ['GOOGL' 'WMT' 'MSFT' 'RIL ' 'TATA']
# eps  :  ['27.82' '4.61' '-1' 'not available' '5.6']
# revenue  :  [ 87 484  85  50  -1]
# price  :  ['845' '65' '64' '1023' 'n.a.']
# people  :  ['larry page' 'n.a.' 'bill gates' 'mukesh ambani' 'ratan tata']

# %%
df = pd.read_csv("data/stock_data.csv", skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv",header=1) # skiprows and header are kind of same
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv", header=None, names = ["col1","col2","col3","col4","col5"])
df
# Out:
#       col1           col2     col3   col4           col5
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv", header=None)
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv", skiprows= 2 , header=None, names = ["col1","col2","col3","col4","col5"] )
df
# Out:
#    col1           col2  col3  col4           col5
# 0   WMT           4.61   484    65           n.a.
# 1  MSFT             -1    85    64     bill gates
# 2  RIL   not available    50  1023  mukesh ambani
# 3  TATA            5.6    -1  n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv", skiprows = 2 , header=None)
df
# Out:
#       0              1    2     3              4
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv",  nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df = pd.read_csv("data/stock_data.csv", header= None,  nrows=2)
df
# Out:
#          0      1        2      3           4
# 0  tickers    eps  revenue  price      people
# 1    GOOGL  27.82       87    845  larry page

# %%
df.shape
# Out:
# (2, 5)

# %% [markdown]
# **Task: How to read random rows from our data**

# %%
df = pd.read_csv("data/stock_data.csv") 
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
# not a number

# %%
df = pd.read_csv("data/stock_data.csv", na_values=["n.a.", "not available"]) 
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv",  na_values = {
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df = pd.read_csv("data/stock_data.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.'],
        'price' : ["n.a."]
    })
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %% [markdown]
# ### <font color="blue">Write to CSV</color>

# %%
df.to_csv("1.csv", index=True) # default

# %%
df.to_csv("2.csv", index=False)

# %%
# another way 
df.to_parquet("3.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 # another way
# ----> 2 df.to_parquet("3.parquet")
#
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/pandas/core/frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
# ...

# %%
mydf = pd.read_parquet("3.parquet")
mydf.info()

# %%
mynew = pd.read_csv("1.csv")
mynew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      int64
#  1   tickers     5 non-null      object
#  2   eps         4 non-null      float64
#  3   revenue     4 non-null      float64
#  4   price       4 non-null      float64
#  5   people      4 non-null      object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
mydf = pd.read_csv("data/stock_data.csv")
mydf
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
mydf.price.replace("n.a." , 12, inplace= True)
mydf.price = mydf.price.astype("float32")
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_14080/413307274.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mydf.price.replace("n.a." , 12, inplace= True)

# %%
mydf
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82       87   845.0     larry page
# 1     WMT           4.61      484    65.0           n.a.
# 2    MSFT             -1       85    64.0     bill gates
# 3    RIL   not available       50  1023.0  mukesh ambani
# 4    TATA            5.6       -1    12.0     ratan tata

# %%
mydf.price[3] = 22
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_14080/367800472.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mydf.price[3] = 22
# ...

# %%
mydf
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87  845.0     larry page
# 1     WMT           4.61      484   65.0           n.a.
# 2    MSFT             -1       85   64.0     bill gates
# 3    RIL   not available       50   22.0  mukesh ambani
# 4    TATA            5.6       -1   12.0     ratan tata

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tickers  5 non-null      object
#  1   eps      5 non-null      object
#  2   revenue  5 non-null      int64
#  3   price    5 non-null      float32
#  4   people   5 non-null      object
# dtypes: float32(1), int64(1), object(3)
# memory usage: 308.0+ bytes

# %%
mydf.isnull().sum()
# Out:
# tickers    0
# eps        0
# revenue    0
# price      0
# people     0
# dtype: int64

# %%
mydf.to_csv("4.csv")
mydf.to_parquet("5.parquet")

# %%
mycsvdf = pd.read_csv("4.csv")
mycsvdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      int64
#  1   tickers     5 non-null      object
#  2   eps         5 non-null      object
#  3   revenue     5 non-null      int64
#  4   price       5 non-null      float64
#  5   people      5 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 368.0+ bytes

# %%
mypdf = pd.read_parquet("5.parquet")
mypdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tickers  5 non-null      object
#  1   eps      5 non-null      object
#  2   revenue  5 non-null      int64
#  3   price    5 non-null      float32
#  4   people   5 non-null      object
# dtypes: float32(1), int64(1), object(3)
# memory usage: 308.0+ bytes

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("6.csv",header=False, index= False)

# %%
df.to_csv("data/7.csv", columns=["tickers","price"], index=False)

# %% [markdown]
# **Task: save 2 columns, last 3 rows only**

# %% [markdown]
# ### <font color="blue">Read Excel</color>

# %%
import pandas as pd 
df = pd.read_excel("data/stock_data.xlsx","Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# **Task:** how to read all excel sheets all at once

# %%
import pandas as pd

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'data not available'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 14.8
    return cell

def convert_eps_cell(cell):
    if cell == "not available":
        return 18.36
    return cell
    
df = pd.read_excel("data/stock_data.xlsx","Sheet1", converters= {
        'people': convert_people_cell,
        'price': convert_price_cell,
         'eps':convert_eps_cell
    })
df.to_excel("   .xlsx", sheet_name="stocks", index=False, startrow=3, startcol=2)
df
# Out:
#   tickers    eps  revenue   price              people
# 0   GOOGL  27.82       87   845.0          larry page
# 1     WMT   4.61      484    65.0  data not available
# 2    MSFT  -1.00       85    64.0          bill gates
# 3    RIL   18.36       50  1023.0       mukesh ambani
# 4    TATA   5.60       -1    14.8          ratan tata

# %% [markdown]
# **Task:** how to append to an existing csv file or excel file same sheet ( instead of overriding )

# %%
# excel file named : Ahmed.xlsx
# save new data in the same file named Ahmed.xlsx
# I want to append my data to the existing data

# %%
# change type of column
#df.eps = df.eps.astype("float43")

# %%
data = pd.read_csv('data/stock_data.csv')
data.to_excel("excel_data.xlsx")

# %% [markdown]
# ### <font color="blue">Write to Excel</color>

# %%
df.to_excel("9.xlsx", sheet_name="aixr2on", index=False)

# %% [markdown]
# **Save two dataframes to two separate sheets in excel**

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

# %%
df_stocks
# Out:
#   tickers  price     pe    eps
# 0   GOOGL    845  30.37  27.82
# 1     WMT     65  14.26   4.61
# 2    MSFT     64  30.97   2.12

# %%
df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
df_weather
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 2  1/3/2017           28   Snow

# %%
with pd.ExcelWriter('10.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks", index= False )
    df_weather.to_excel(writer, sheet_name="weather")

# %%
def save_excel_in_one_file(filename, dataframes):
    counter = 0 
    with pd.ExcelWriter (filename + ".xlsx") as writer : 
        for dataframe in dataframes :
            dataframe.to_excel(writer, sheet_name = str(counter))
            counter += 1

# %%
save_excel_in_one_file("11", [df_stocks, df_weather])

# %%
# Overide ( Wrong method )
df_stocks.to_excel('a.xlsx', sheet_name="stocks")
df_weather.to_excel('a.xlsx', sheet_name="weather")

# %% [markdown]
# ### Handling Missing Data:
# **fillna, interpolate, dropna**

# %%
df = pd.read_csv("data/weather_dataaa.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.day.dtype
# Out:
# dtype('O')

# %%
df["day"] = pd.to_datetime(df["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df["month"] = df.day.dt.month 
df
# Out:
#          day  temperature  windspeed   event  month
# 0 2017-01-01         32.0        6.0    Rain      1
# 1 2017-01-04          NaN        9.0   Sunny      1
# 2 2017-01-05         28.0        NaN    Snow      1
# 3 2017-01-06          NaN        7.0     NaN      1
# 4 2017-01-07         32.0        NaN    Rain      1
# 5 2017-01-08          NaN        NaN   Sunny      1
# 6 2017-01-09          NaN        NaN     NaN      1
# 7 2017-01-10         34.0        8.0  Cloudy      1
# 8 2017-01-11         40.0       12.0   Sunny      1

# %%
df["temp_day"] = df.day.dt.day 
df
# Out:
#          day  temperature  windspeed   event  month  temp_day
# 0 2017-01-01         32.0        6.0    Rain      1         1
# 1 2017-01-04          NaN        9.0   Sunny      1         4
# 2 2017-01-05         28.0        NaN    Snow      1         5
# 3 2017-01-06          NaN        7.0     NaN      1         6
# 4 2017-01-07         32.0        NaN    Rain      1         7
# 5 2017-01-08          NaN        NaN   Sunny      1         8
# 6 2017-01-09          NaN        NaN     NaN      1         9
# 7 2017-01-10         34.0        8.0  Cloudy      1        10
# 8 2017-01-11         40.0       12.0   Sunny      1        11

# %%
df["year"] = df.day.dt.year  
df
# Out:
#          day  temperature  windspeed   event  month  temp_day  year
# 0 2017-01-01         32.0        6.0    Rain      1         1  2017
# 1 2017-01-04          NaN        9.0   Sunny      1         4  2017
# 2 2017-01-05         28.0        NaN    Snow      1         5  2017
# 3 2017-01-06          NaN        7.0     NaN      1         6  2017
# 4 2017-01-07         32.0        NaN    Rain      1         7  2017
# 5 2017-01-08          NaN        NaN   Sunny      1         8  2017
# 6 2017-01-09          NaN        NaN     NaN      1         9  2017
# 7 2017-01-10         34.0        8.0  Cloudy      1        10  2017
# 8 2017-01-11         40.0       12.0   Sunny      1        11  2017

# %%
df.day.dtype
# Out:
# dtype('<M8[ns]')

# %%
df = pd.read_csv("data/weather_dataaa.csv", parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df = pd.read_csv("data/weather_dataaa.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.day = pd.to_datetime(df.day)
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.day[0], type(df.day[0])
# Out:
# (Timestamp('2017-01-01 00:00:00'), pandas._libs.tslibs.timestamps.Timestamp)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df["month"] = df.day.dt.month 
df
# Out:
#          day  temperature  windspeed   event  month
# 0 2017-01-01         32.0        6.0    Rain      1
# 1 2017-01-04          NaN        9.0   Sunny      1
# 2 2017-01-05         28.0        NaN    Snow      1
# 3 2017-01-06          NaN        7.0     NaN      1
# 4 2017-01-07         32.0        NaN    Rain      1
# 5 2017-01-08          NaN        NaN   Sunny      1
# 6 2017-01-09          NaN        NaN     NaN      1
# 7 2017-01-10         34.0        8.0  Cloudy      1
# 8 2017-01-11         40.0       12.0   Sunny      1

# %%
df["day_of_month"] = df.day.dt.day 
df
# Out:
#          day  temperature  windspeed   event  month  day_of_month
# 0 2017-01-01         32.0        6.0    Rain      1             1
# 1 2017-01-04          NaN        9.0   Sunny      1             4
# 2 2017-01-05         28.0        NaN    Snow      1             5
# 3 2017-01-06          NaN        7.0     NaN      1             6
# 4 2017-01-07         32.0        NaN    Rain      1             7
# 5 2017-01-08          NaN        NaN   Sunny      1             8
# 6 2017-01-09          NaN        NaN     NaN      1             9
# 7 2017-01-10         34.0        8.0  Cloudy      1            10
# 8 2017-01-11         40.0       12.0   Sunny      1            11

# %%
df["year"] = df.day.dt.year 
df
# Out:
#          day  temperature  windspeed   event  month  day_of_month  year
# 0 2017-01-01         32.0        6.0    Rain      1             1  2017
# 1 2017-01-04          NaN        9.0   Sunny      1             4  2017
# 2 2017-01-05         28.0        NaN    Snow      1             5  2017
# 3 2017-01-06          NaN        7.0     NaN      1             6  2017
# 4 2017-01-07         32.0        NaN    Rain      1             7  2017
# 5 2017-01-08          NaN        NaN   Sunny      1             8  2017
# 6 2017-01-09          NaN        NaN     NaN      1             9  2017
# 7 2017-01-10         34.0        8.0  Cloudy      1            10  2017
# 8 2017-01-11         40.0       12.0   Sunny      1            11  2017

# %%
df["month_year"] = df.day.dt.to_period("M") 
df
# Out:
#          day  temperature  windspeed   event  month  day_of_month  year  \
# 0 2017-01-01         32.0        6.0    Rain      1             1  2017
# 1 2017-01-04          NaN        9.0   Sunny      1             4  2017
# 2 2017-01-05         28.0        NaN    Snow      1             5  2017
# 3 2017-01-06          NaN        7.0     NaN      1             6  2017
# 4 2017-01-07         32.0        NaN    Rain      1             7  2017
# 5 2017-01-08          NaN        NaN   Sunny      1             8  2017
# 6 2017-01-09          NaN        NaN     NaN      1             9  2017
# 7 2017-01-10         34.0        8.0  Cloudy      1            10  2017
# 8 2017-01-11         40.0       12.0   Sunny      1            11  2017
#
#   month_year
# 0    2017-01
# 1    2017-01
# 2    2017-01
# 3    2017-01
# 4    2017-01
# 5    2017-01
# 6    2017-01
# 7    2017-01
# 8    2017-01

# %%
df
# Out:
#          day  temperature  windspeed   event  month  day_of_month  year  \
# 0 2017-01-01         32.0        6.0    Rain      1             1  2017
# 1 2017-01-04          NaN        9.0   Sunny      1             4  2017
# 2 2017-01-05         28.0        NaN    Snow      1             5  2017
# 3 2017-01-06          NaN        7.0     NaN      1             6  2017
# 4 2017-01-07         32.0        NaN    Rain      1             7  2017
# 5 2017-01-08          NaN        NaN   Sunny      1             8  2017
# 6 2017-01-09          NaN        NaN     NaN      1             9  2017
# 7 2017-01-10         34.0        8.0  Cloudy      1            10  2017
# 8 2017-01-11         40.0       12.0   Sunny      1            11  2017
#
#   month_year
# 0    2017-01
# 1    2017-01
# 2    2017-01
# 3    2017-01
# 4    2017-01
# 5    2017-01
# 6    2017-01
# 7    2017-01
# 8    2017-01

# %% [markdown]
# ## <font>fillna</font>

# %% [markdown]
# <font>**Fill all NaN with one specific value**</font>

# %%
df = pd.read_csv("data/weather_dataaa.csv", parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
new_df = df.fillna(888)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04        888.0        9.0   Sunny
# 2 2017-01-05         28.0      888.0    Snow
# 3 2017-01-06        888.0        7.0     888
# 4 2017-01-07         32.0      888.0    Rain
# 5 2017-01-08        888.0      888.0   Sunny
# 6 2017-01-09        888.0      888.0     888
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
new_df = df.fillna("ahmed")
new_df
# Out:
#          day temperature windspeed   event
# 0 2017-01-01        32.0       6.0    Rain
# 1 2017-01-04       ahmed       9.0   Sunny
# 2 2017-01-05        28.0     ahmed    Snow
# 3 2017-01-06       ahmed       7.0   ahmed
# 4 2017-01-07        32.0     ahmed    Rain
# 5 2017-01-08       ahmed     ahmed   Sunny
# 6 2017-01-09       ahmed     ahmed   ahmed
# 7 2017-01-10        34.0       8.0  Cloudy
# 8 2017-01-11        40.0      12.0   Sunny

# %%
new_df.dtypes
# Out:
# day            datetime64[ns]
# temperature            object
# windspeed              object
# event                  object
# dtype: object

# %% [markdown]
# <font>**Fill na using column names and dict**</font>

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': df["windspeed"].mean(),
        'event': 'No event'
    })
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        8.4      Snow
# 3 2017-01-06          0.0        7.0  No event
# 4 2017-01-07         32.0        8.4      Rain
# 5 2017-01-08          0.0        8.4     Sunny
# 6 2017-01-09          0.0        8.4  No event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# <font>**Use method to determine to fill na values**</font>

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         28.0        9.0   Sunny
# 2 2017-01-05         28.0        7.0    Snow
# 3 2017-01-06         32.0        7.0    Rain
# 4 2017-01-07         32.0        8.0    Rain
# 5 2017-01-08         34.0        8.0   Sunny
# 6 2017-01-09         34.0        8.0  Cloudy
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# <font color="purple">**Use of axis**</font>

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
#          day temperature windspeed   event
# 0 2017-01-01        32.0       6.0    Rain
# 1 2017-01-04         9.0       9.0   Sunny
# 2 2017-01-05        28.0      Snow    Snow
# 3 2017-01-06         7.0       7.0     NaN
# 4 2017-01-07        32.0      Rain    Rain
# 5 2017-01-08       Sunny     Sunny   Sunny
# 6 2017-01-09         NaT       NaT     NaT
# 7 2017-01-10        34.0       8.0  Cloudy
# 8 2017-01-11        40.0      12.0   Sunny

# %%
new_df = df.fillna(method="bfill", axis = 1 )  # axis is either "index" or "columns"
new_df
# Out:
#                    day temperature windspeed   event
# 0  2017-01-01 00:00:00        32.0       6.0    Rain
# 1  2017-01-04 00:00:00         9.0       9.0   Sunny
# 2  2017-01-05 00:00:00        28.0      Snow    Snow
# 3  2017-01-06 00:00:00         7.0       7.0     NaN
# 4  2017-01-07 00:00:00        32.0      Rain    Rain
# 5  2017-01-08 00:00:00       Sunny     Sunny   Sunny
# 6  2017-01-09 00:00:00         NaT       NaT     NaT
# 7  2017-01-10 00:00:00        34.0       8.0  Cloudy
# 8  2017-01-11 00:00:00        40.0      12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="ffill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
#          day          temperature            windspeed                event
# 0 2017-01-01                 32.0                  6.0                 Rain
# 1 2017-01-04  2017-01-04 00:00:00                  9.0                Sunny
# 2 2017-01-05                 28.0                 28.0                 Snow
# 3 2017-01-06  2017-01-06 00:00:00                  7.0                  7.0
# 4 2017-01-07                 32.0                 32.0                 Rain
# 5 2017-01-08  2017-01-08 00:00:00  2017-01-08 00:00:00                Sunny
# 6 2017-01-09  2017-01-09 00:00:00  2017-01-09 00:00:00  2017-01-09 00:00:00
# 7 2017-01-10                 34.0                  8.0               Cloudy
# 8 2017-01-11                 40.0                 12.0                Sunny

# %%
new_df.dtypes
# Out:
# day            object
# temperature    object
# windspeed      object
# event          object
# dtype: object

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df.copy()
newdf.temperature.fillna(method="ffill", inplace= True)
newdf
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06         28.0        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         32.0        NaN   Sunny
# 6 2017-01-09         32.0        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# <font>**limit parameter**</font>

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="ffill",limit=2)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        NaN   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="ffill",limit=3)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### <font>interpolate</font>

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index("day", inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %% [markdown]
# **Task 3: replace data in csv file ( interpolate )**    <br>
# case 1 : 32, NAN, NAN, NAN, 30 <br>
# case 2 : 32, 30, NAN , NAN , NAN <br>

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df.temperature = new_df.temperature.astype("int32")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01           32       6.00    Rain
# 2017-01-04           29       9.00   Sunny
# 2017-01-05           28       8.00    Snow
# 2017-01-06           30       7.00     NaN
# 2017-01-07           32       7.25    Rain
# 2017-01-08           32       7.50   Sunny
# 2017-01-09           33       7.75     NaN
# 2017-01-10           34       8.00  Cloudy
# 2017-01-11           40      12.00   Sunny

# %%
new_df.dtypes
# Out:
# temperature      int32
# windspeed      float64
# event           object
# dtype: object

# %% [markdown]
# **Notice that in above temperature on 2017-01-04 is 29 instead of 30 (in plain linear interpolate)**

# %% [markdown]
# **There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc.
# Just google "dataframe interpolate" to see complete documentation**

# %% [markdown]
# ### <font>dropna</font>

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna( how ='all' )
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df.dropna( subset = "temperature"  )
newdf
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna( thresh = 2 ) 
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### <font>Inserting Missing Dates</font>

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dr = pd.date_range("01-01-2017","01-11-2017")
print(dr)
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
idx = pd.DatetimeIndex(dr)
df.reindex(idx)
# NAT --> not a time ( datatype = datetime )
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newdf = df.drop(["event","windspeed"], axis = 1) #drop columns
newdf
# Out:
#             temperature
# day
# 2017-01-01         32.0
# 2017-01-04          NaN
# 2017-01-05         28.0
# 2017-01-06          NaN
# 2017-01-07         32.0
# 2017-01-08          NaN
# 2017-01-09          NaN
# 2017-01-10         34.0
# 2017-01-11         40.0

# %%
for i in df.columns: 
    if df[i].isna().sum() > 3 :
        print(i)
# Out:
# temperature
# windspeed

# %%
for column in df.columns: 
    if df[column].isna().sum() > 3 :
        df.drop(column, axis= 1 , inplace= True )

# %%
df
# Out:
#              event
# day
# 2017-01-01    Rain
# 2017-01-04   Sunny
# 2017-01-05    Snow
# 2017-01-06     NaN
# 2017-01-07    Rain
# 2017-01-08   Sunny
# 2017-01-09     NaN
# 2017-01-10  Cloudy
# 2017-01-11   Sunny

# %%
def number_of_missing_values(dataframe, column): 
    return dataframe[column].isna().sum()

# %%
number_of_missing_values(df, "event")
# Out:
# 2

# %%
for column in df.columns: 
    if df[column].isna().sum() > 3 :
        df.drop(column, axis= 1 , inplace= True )

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - replace method</font>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/weather_data_replace.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df.describe().T[["mean"]]
# Out:
#                      mean
# temperature -28548.714286
# windspeed   -28567.285714

# %%
df.describe().loc[["mean"]]
# Out:
#        temperature     windspeed
# mean -28548.714286 -28567.285714

# %%
df.iloc[:, 1: 3].mean()
# Out:
# temperature   -28548.714286
# windspeed     -28567.285714
# dtype: float64

# %%
# there are no missing data, inconsistant
df.isna().sum()
# Out:
# day            0
# temperature    0
# windspeed      0
# event          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          7 non-null      object
#  1   temperature  7 non-null      int64
#  2   windspeed    7 non-null      int64
#  3   event        7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 352.0+ bytes

# %%
for i in df.columns:
    try:
        print(i," : " ,df[i].mean())
    except:
        print("Column " + i + " is not numeric")
# Out:
# Column day is not numeric
# temperature  :  -28548.714285714286
# windspeed  :  -28567.285714285714
# Column event is not numeric

# %%
mintemp = -100
maxtemp = 100 
df [ (df.temperature < mintemp) | (df.temperature > maxtemp)]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017       -99999          7  Sunny
# 3  1/4/2017       -99999          7      0

# %%
minspeed = 0 
df [ df.windspeed < minspeed ]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28     -99999  Snow
# 4  1/5/2017           32     -99999  Rain

# %%
df [~((df.temperature < mintemp) | (df.temperature > maxtemp))]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 2  1/3/2017           28     -99999   Snow
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# **Replacing single value**

# %%
new_df = df.replace(-99999, value=5)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            5          7  Sunny
# 2  1/3/2017           28          5   Snow
# 3  1/4/2017            5          7      0
# 4  1/5/2017           32          5   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# **Replacing list with single value**

# %%
new_df = df.replace(to_replace=[-99999,-88888, 10, '0'], value=5)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            5          7  Sunny
# 2  1/3/2017           28          5   Snow
# 3  1/4/2017            5          7      5
# 4  1/5/2017           32          5   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      5

# %% [markdown]
# **Replacing per column**

# %%
new_df = df.replace({
        'temperature': -99999,
        'windspeed': -99999,
        'day': '1/1/2017',
        'event': '0'
    }, np.nan)
new_df
# Out:
#         day  temperature  windspeed  event
# 0       NaN         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %% [markdown]
# **Replacing by using mapping**

# %%
new_df = df.replace({
        -99999: np.nan,
        '0': 'Sunny',
    })
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0  Sunny
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
type(np.nan)
# Out:
# float

# %% [markdown]
# **Regex**

# %%
newdf = df.copy()
templist = newdf.temperature.tolist()
for i in range(len(templist)):
    templist[i] = str(templist[i]) + "C"
newdf.temperature = templist 
newdf
# Out:
#         day temperature  windspeed  event
# 0  1/1/2017         32C          6   Rain
# 1  1/2/2017     -99999C          7  Sunny
# 2  1/3/2017         28C     -99999   Snow
# 3  1/4/2017     -99999C          7      0
# 4  1/5/2017         32C     -99999   Rain
# 5  1/6/2017         31C          2  Sunny
# 6  1/6/2017         34C          5      0

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
new_df = newdf.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},'A', regex=True) 
new_df
# Out:
#         day temperature  windspeed  event
# 0  1/1/2017         32A          6   Rain
# 1  1/2/2017     -99999A          7  Sunny
# 2  1/3/2017         28A     -99999   Snow
# 3  1/4/2017     -99999A          7      0
# 4  1/5/2017         32A     -99999   Rain
# 5  1/6/2017         31A          2  Sunny
# 6  1/6/2017         34A          5      0

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
new_df = newdf.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},'', regex=True) 
new_df
# Out:
#         day temperature  windspeed  event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017      -99999          7  Sunny
# 2  1/3/2017          28     -99999   Snow
# 3  1/4/2017      -99999          7      0
# 4  1/5/2017          32     -99999   Rain
# 5  1/6/2017          31          2  Sunny
# 6  1/6/2017          34          5      0

# %%
new_df = newdf.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},{'temperature': 'A', 'windspeed': 'H'} , regex=True) 
new_df
# Out:
#         day temperature  windspeed  event
# 0  1/1/2017         32A          6   Rain
# 1  1/2/2017     -99999A          7  Sunny
# 2  1/3/2017         28A     -99999   Snow
# 3  1/4/2017     -99999A          7      0
# 4  1/5/2017         32A     -99999   Rain
# 5  1/6/2017         31A          2  Sunny
# 6  1/6/2017         34A          5      0

# %%
new_df.dtypes
# Out:
# day            object
# temperature    object
# windspeed       int64
# event          object
# dtype: object

# %%
new_df = new_df.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},{'temperature': '', 'windspeed': ''} , regex=True)

# %%
new_df
# Out:
#         day temperature  windspeed  event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017      -99999          7  Sunny
# 2  1/3/2017          28     -99999   Snow
# 3  1/4/2017      -99999          7      0
# 4  1/5/2017          32     -99999   Rain
# 5  1/6/2017          31          2  Sunny
# 6  1/6/2017          34          5      0

# %%
new_df.temperature = new_df.temperature.astype(np.float32)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017     -99999.0          7  Sunny
# 2  1/3/2017         28.0     -99999   Snow
# 3  1/4/2017     -99999.0          7      0
# 4  1/5/2017         32.0     -99999   Rain
# 5  1/6/2017         31.0          2  Sunny
# 6  1/6/2017         34.0          5      0

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          7 non-null      object
#  1   temperature  7 non-null      float32
#  2   windspeed    7 non-null      int64
#  3   event        7 non-null      object
# dtypes: float32(1), int64(1), object(2)
# memory usage: 324.0+ bytes

# %% [markdown]
# **Replacing list with another list**

# %%
df = pd.DataFrame({
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica'],
     'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional']
})
df
# Out:
#    student        score
# 0      rob  exceptional
# 1     maya      average
# 2  parthiv         good
# 3      tom         poor
# 4   julian      average
# 5    erica  exceptional

# %%
df.score.value_counts()
# Out:
# score
# exceptional    2
# average        2
# good           1
# poor           1
# Name: count, dtype: int64

# %%
df.replace(['poor', 'good', 'average', 'exceptional'], [4,8,16,30])
# Out:
#    student  score
# 0      rob     30
# 1     maya     16
# 2  parthiv      8
# 3      tom      4
# 4   julian     16
# 5    erica     30

# %%
df
# Out:
#    student        score
# 0      rob  exceptional
# 1     maya      average
# 2  parthiv         good
# 3      tom         poor
# 4   julian      average
# 5    erica  exceptional

# %% [markdown]
# **Task: replace data in specific columns with specific values**
# <br>
# *Example:*
#
# Name     Age
# Ahmed     23
# Ali       20
# Omar      70

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [2,4,10,30] , inplace=True)

# %%
df
# Out:
#    student  score
# 0      rob     30
# 1     maya      4
# 2  parthiv     10
# 3      tom      2
# 4   julian      4
# 5    erica     30

# %%
def replcevalues():
    result = []
    for i in df.score:

        if int(i) < 5 :
            result.append("Failed")
        elif int(i) > 5 and int(i) < 20:
            result.append("Weak")
        else:
            result.append("Okay")
            
    print(result)
    return result

# %%
df["numnericalscores"]= replcevalues()
df
# Out:
# ['Okay', 'Failed', 'Weak', 'Failed', 'Failed', 'Okay']
#    student  score numnericalscores
# 0      rob     30             Okay
# 1     maya      4           Failed
# 2  parthiv     10             Weak
# 3      tom      2           Failed
# 4   julian      4           Failed
# 5    erica     30             Okay

# %% [markdown]
# **Task: how to detect and remove outliers using pandas**

# %% [markdown]
# ## Group By

# %% [markdown]
# **In this tutorial we are going to look at weather data from various cities and see how group by can be used to run some analytics.**

# %%
import pandas as pd
df = pd.read_csv("data/weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
newyork = df[ df.city == "new york"]
newyork
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
newyork.temperature.mean()
# Out:
# 32.25

# %%
# another way
df[df.city == "new york"]["temperature"].mean()
# Out:
# 32.25

# %%
paris = df[ df.city == "paris"]
paris
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
paris.temperature.mean()
# Out:
# 47.75

# %%
parismean = df.temperature[ df.city == "paris"].mean()
parismean
# Out:
# 47.75

# %%
# Data Range
print(df.temperature.min())
print(df.temperature.max())
print(abs(df.temperature.min()-df.temperature.max()))
# Out:
# 28
# 92
# 64

# %%
cities = df.city.unique().tolist()
cities
# Out:
# ['new york', 'mumbai', 'paris']

# %%
for city in cities: 
    print(city, df[ df.city == city].temperature.mean())
# Out:
# new york 32.25
# mumbai 88.5
# paris 47.75

# %% [markdown]
# ### For this dataset, get following answers,
# #### 1. What was the maximum temperature in each of these 3 cities?
# #### 2. What was the average windspeed in each of these 3 cities?

# %%
groups = df.groupby("city") # column name
groups

# %% [markdown]
# **DataFrameGroupBy object looks something like below,**

# %% [markdown]
# <img src="group_by_cities.png">

# %% [markdown]
# **This is similar to SQL,**
#
# **SELECT * from weather_data GROUP BY city**

# %%
newyork = groups.get_group("new york")
newyork
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
groups.mean( numeric_only = True )
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
groups.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
groups.max()[["temperature", "windspeed" ]]
# Out:
#           temperature  windspeed
# city
# mumbai             92         15
# new york           36         12
# paris              54         20

# %%
groups.max(numeric_only = True)
# Out:
#           temperature  windspeed
# city
# mumbai             92         15
# new york           36         12
# paris              54         20

# %%
groups.max()[["temperature"]]
# Out:
#           temperature
# city
# mumbai             92
# new york           36
# paris              54

# %%
groups.mean(numeric_only =True)[["windspeed"]]
# Out:
#           windspeed
# city
# mumbai         9.25
# new york       8.00
# paris         12.75

# %%
df.groupby("city").mean(numeric_only =True)
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
df.groupby("city").mean(numeric_only =True)[["temperature"]]
# Out:
#           temperature
# city
# mumbai          88.50
# new york        32.25
# paris           47.75

# %%
df.groupby("city").sum(numeric_only =True)[["temperature"]]
# Out:
#           temperature
# city
# mumbai            354
# new york          129
# paris             191

# %% [markdown]
# **This method of splitting your dataset in smaller groups and then applying an operation
# (such as min or max) to get aggregate result is called Split-Apply-Combine. It is illustrated in a diagram below**

# %% [markdown]
# <img src="split_apply_combine.png">

# %%
groups.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
groups.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
groups.describe(include = "all")
# Out:
#            day                                                      ...  \
#          count unique       top freq mean  std  min  25%  50%  75%  ...
# city                                                                ...
# mumbai       4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
# new york     4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
# paris        4      4  1/1/2017    1  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#           event
#          unique     top freq mean  std  min  25%  50%  75%  max
# city
# mumbai        3     Fog    2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# new york      3   Sunny    2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# paris         2  Cloudy    3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 44 columns]

# %%
groups.describe()["temperature"]
# Out:
#           count   mean       std   min    25%   50%    75%   max
# city
# mumbai      4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york    4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris       4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0

# %%
info = groups.describe()["temperature"][["count", "mean", "std", "min", "max"]]
info
# Out:
#           count   mean       std   min   max
# city
# mumbai      4.0  88.50  3.109126  85.0  92.0
# new york    4.0  32.25  3.304038  28.0  36.0
# paris       4.0  47.75  5.315073  42.0  54.0

# %%
info.rename({"max": "max temp", "std" :"standard diviation"}, inplace= True , axis = 1 )
info
# Out:
#           count   mean  standard diviation   min  max temp
# city
# mumbai      4.0  88.50            3.109126  85.0      92.0
# new york    4.0  32.25            3.304038  28.0      36.0
# paris       4.0  47.75            5.315073  42.0      54.0

# %%
# number of rows in each group 
groups.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
groups.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# %matplotlib inline
groups.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.11;0.775x0.77)
# new york    AxesSubplot(0.125,0.11;0.775x0.77)
# paris       AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# <h4>Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups<h4>
# <ol>
#     <li>Days when temperature was between 80 and 90</li>
#     <li>Days when it was between 50 and 60</li>
#     <li>Days when it was anything else</li>
# </ol>

# %% [markdown]
# For this you need to write custom grouping function and pass that to groupby

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
def grouper(df, index, column): 
    if 2 <= df[column].loc[index] <= 5:  # if df[windspeed].loc[index]
        return '2-5'
    elif 6 <= df[column].loc[index] <= 10:
        return '6-10'
    else:
        return 'others'

# %%
g = df.groupby(lambda x : grouper(df, x, 'windspeed'))
g

# %%
def custom_group ( dataframe , column_name ) :
    return dataframe.groupby(lambda x : grouper(df, x, column_name ))

# %%
mynewgroup = custom_group(df, "windspeed")

# %%
mynewgroup.get_group("others")
# Out:
#         day      city  temperature  windspeed   event
# 2  1/3/2017  new york           28         12    Snow
# 5  1/2/2017    mumbai           85         12     Fog
# 6  1/3/2017    mumbai           87         15     Fog
# 8  1/1/2017     paris           45         20   Sunny
# 9  1/2/2017     paris           50         13  Cloudy

# %% [markdown]
# **Task: What is lambda expression?** <br>
# **Task: How to custom group dataframe without lamda expression**

# %%
g.get_group("others")
# Out:
#         day      city  temperature  windspeed   event
# 2  1/3/2017  new york           28         12    Snow
# 5  1/2/2017    mumbai           85         12     Fog
# 6  1/3/2017    mumbai           87         15     Fog
# 8  1/1/2017     paris           45         20   Sunny
# 9  1/2/2017     paris           50         13  Cloudy

# %%
g.get_group("6-10")
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 3   1/4/2017  new york           33          7   Sunny
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g.get_group("2-5")
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 7  1/4/2017  mumbai           92          5   Rain

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
def grouper(df, i, colname): 
    if 2 <= df[colname].loc[i] <= 5:  # if df[windspeed].loc[index]
        return 'group1'
    elif 6 <= df[colname].loc[i] <= 10:
        return 'group2'
    else:
        return 'others group'

# %%
#newgroups = dfname.groupby(lambda x : grouper(df, x, 'windspeed'))

# %%
df.temperature.min()
# Out:
# 28

# %%
df.temperature.max()
# Out:
# 92

# %%
bins = [28, 35, 45, 80, 90]  
labels = ['Cold', 'Mild', 'Warm', 'Hot'] 


df['Temperature_Group'] = pd.cut(df['temperature'], bins=bins, labels=labels)


grouped = df.groupby('Temperature_Group')

# %%
grouped.mean(numeric_only= True )
# Out:
#                    temperature  windspeed
# Temperature_Group
# Cold                 32.500000   6.500000
# Mild                 41.000000  12.333333
# Warm                 52.000000  10.500000
# Hot                  87.333333  10.666667

# %%
grouped.get_group("Hot")
# Out:
#          day      city  temperature  windspeed   event Temperature_Group
# 1   1/2/2017  new york           36          7   Sunny               Hot
# 8   1/1/2017     paris           45         20   Sunny               Hot
# 9   1/2/2017     paris           50         13  Cloudy               Hot
# 11  1/4/2017     paris           42         10  Cloudy               Hot

# %% [markdown]
# ### Concatenate

# %% [markdown]
# ## <font color='blue'>Basic Concatenation</font>

# %%
import pandas as pd

italy_weather = pd.DataFrame({
    "city": ["Rome","Napoli","Milan"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
italy_weather
# Out:
#      city  temperature  humidity
# 0    Rome           32        80
# 1  Napoli           45        60
# 2   Milan           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([italy_weather, us_weather])
df
# Out:
#        city  temperature  humidity
# 0      Rome           32        80
# 1    Napoli           45        60
# 2     Milan           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# ## <font color='blue'>Ignore Index</font>

# %%
df = pd.concat([italy_weather, us_weather], ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0      Rome           32        80
# 1    Napoli           45        60
# 2     Milan           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
spain_weather = pd.DataFrame({
    "city": ["Madrid","Balad El Waleed","Malaga"],
    "humidity": [80, 60, 78],
    "temperature": [32,45,30]
})
spain_weather
# Out:
#               city  humidity  temperature
# 0           Madrid        80           32
# 1  Balad El Waleed        60           45
# 2           Malaga        78           30

# %%
uk_weather = pd.DataFrame({
    "city": ["London","Manchester","Leeds"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
uk_weather
# Out:
#          city  temperature  humidity
# 0      London           21        68
# 1  Manchester           14        65
# 2       Leeds           35        75

# %%
df = pd.concat([spain_weather, uk_weather])
df
# Out:
#               city  humidity  temperature
# 0           Madrid        80           32
# 1  Balad El Waleed        60           45
# 2           Malaga        78           30
# 0           London        68           21
# 1       Manchester        65           14
# 2            Leeds        75           35

# %%
df.to_csv("concatinatedDFs.csv" , index=False)

# %%
egypt_weather = pd.DataFrame({
    "city": ["October","Giza","Cairo","Alex"],
    "temperature": [32,45,30, 32],
    "humidity": [80, 60, 78, 23]
})
egypt_weather
# Out:
#       city  temperature  humidity
# 0  October           32        80
# 1     Giza           45        60
# 2    Cairo           30        78
# 3     Alex           32        23

# %%
df = pd.concat([italy_weather, us_weather, egypt_weather], ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0      Rome           32        80
# 1    Napoli           45        60
# 2     Milan           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75
# 6   October           32        80
# 7      Giza           45        60
# 8     Cairo           30        78
# 9      Alex           32        23

# %%
df = pd.concat([italy_weather, us_weather, egypt_weather,  spain_weather , uk_weather ], ignore_index=True)
df
# Out:
#                city  temperature  humidity
# 0              Rome           32        80
# 1            Napoli           45        60
# 2             Milan           30        78
# 3          new york           21        68
# 4           chicago           14        65
# 5           orlando           35        75
# 6           October           32        80
# 7              Giza           45        60
# 8             Cairo           30        78
# 9              Alex           32        23
# 10           Madrid           32        80
# 11  Balad El Waleed           45        60
# 12           Malaga           30        78
# 13           London           21        68
# 14       Manchester           14        65
# 15            Leeds           35        75

# %% [markdown]
# ## <font color='blue'>Concatenation And Keys</font>

# %%
df = pd.concat([italy_weather, us_weather], keys=["italy", "us"])
df
# Out:
#              city  temperature  humidity
# italy 0      Rome           32        80
#       1    Napoli           45        60
#       2     Milan           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["us"] #location
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df.loc["italy"]
# Out:
#      city  temperature  humidity
# 0    Rome           32        80
# 1  Napoli           45        60
# 2   Milan           30        78

# %%
df.iloc[0]
# Out:
# city           Rome
# temperature      32
# humidity         80
# Name: (italy, 0), dtype: object

# %%
df.iloc[1]
# Out:
# city           Napoli
# temperature        45
# humidity           60
# Name: (italy, 1), dtype: object

# %%
df.to_csv("newdf.csv" , index_label=True)

# %% [markdown]
# ## <font color='blue'>Concatenation Using Index</font>

# %%
temperature_df = pd.DataFrame({
    "city": ["madrid","valiencia","barcelona"],
    "temperature": [32,45,30],
}, index=[4,5,2])
temperature_df
# Out:
#         city  temperature
# 4     madrid           32
# 5  valiencia           45
# 2  barcelona           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["berlin","hamburg"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#       city  windspeed
# 1   berlin          7
# 0  hamburg         12

# %%
df = pd.concat([temperature_df,windspeed_df], ignore_index= True)
df
# Out:
#         city  temperature  windspeed
# 0     madrid         32.0        NaN
# 1  valiencia         45.0        NaN
# 2  barcelona         30.0        NaN
# 3     berlin          NaN        7.0
# 4    hamburg          NaN       12.0

# %%
df = pd.concat([temperature_df,windspeed_df])
df
# Out:
#         city  temperature  windspeed
# 4     madrid         32.0        NaN
# 5  valiencia         45.0        NaN
# 2  barcelona         30.0        NaN
# 1     berlin          NaN        7.0
# 0    hamburg          NaN       12.0

# %% [markdown]
# **Task : How to sort dataframe by index, how to sort dataframe by specific column**

# %%
df = pd.concat([temperature_df,windspeed_df], axis= 1)
df
# Out:
#         city  temperature     city  windspeed
# 4     madrid         32.0      NaN        NaN
# 5  valiencia         45.0      NaN        NaN
# 2  barcelona         30.0      NaN        NaN
# 1        NaN          NaN   berlin        7.0
# 0        NaN          NaN  hamburg       12.0

# %% [markdown]
# ## <font color='blue'>Concatenate dataframe with series</font>

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s.dtype
# Out:
# dtype('O')

# %%
df = pd.concat([df,s],axis=1)
df
# Out:
#         city  temperature     city  windspeed  event
# 4     madrid         32.0      NaN        NaN    NaN
# 5  valiencia         45.0      NaN        NaN    NaN
# 2  barcelona         30.0      NaN        NaN   Rain
# 1        NaN          NaN   berlin        7.0    Dry
# 0        NaN          NaN  hamburg       12.0  Humid

# %% [markdown]
# ### Merge

# %% [markdown]
# ### Basic Merge Using a Dataframe Column

# %%
import pandas as pd
df1 = pd.DataFrame({
    "City": ["New York","Chicago","Hollywood"],
    "Temperature": [21,14,35],
})
df1
# Out:
#         City  Temperature
# 0   New York           21
# 1    Chicago           14
# 2  Hollywood           35

# %%
df2 = pd.DataFrame({
    "City": ["Chicago","New York","Orlando", "California"],
    "Humidity": [65,68,75, 56],
})
df2
# Out:
#          City  Humidity
# 0     Chicago        65
# 1    New York        68
# 2     Orlando        75
# 3  California        56

# %%
df3 = pd.merge(df1, df2, on="City")
df3
# Out:
#        City  Temperature  Humidity
# 0  New York           21        68
# 1   Chicago           14        65

# %% [markdown]
# ## <font>Type Of DataBase Joins</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "boston"],
    "temperature": [21,14,35, 38],
}) 
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35
# 3    boston           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3 = pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3     boston         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35
# 3    boston           38

# %%
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3 = pd.merge(df1   ,   df2,on="city",how="left")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21      68.0
# 1   chicago           14      65.0
# 2   orlando           35       NaN
# 3    boston           38       NaN

# %%
df3= pd.merge(df2,df1,on="city",how="left")
df3
# Out:
#         city  humidity  temperature
# 0    chicago        65         14.0
# 1   new york        68         21.0
# 2  san diego        71          NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %% [markdown]
# ## <font>indicator flag</font>

# %%
df3 = pd.merge(df1,df2,on="city",how="outer",indicator=True)
df3
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3     boston         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %% [markdown]
# **Task: how to merge more than 2 dataframes at the same time**

# %% [markdown]
# ## <font>suffixes</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=('_first','_second'))
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0   new york               21.0            65.0                14.0
# 1    chicago               14.0            68.0                21.0
# 2    orlando               35.0            71.0                 NaN
# 3  baltimore               38.0            75.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0             68.0
# 1             65.0
# 2              NaN
# 3              NaN
# 4             71.0

# %%
df3 [["temperature_first", "temperature_second"]]
# Out:
#    temperature_first  temperature_second
# 0               38.0                 NaN
# 1               14.0                21.0
# 2               21.0                14.0
# 3               35.0                 NaN
# 4                NaN                35.0

# %%
df3["tempsum"] = df3 ["temperature_first"] + df3[ "temperature_second"]
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0  baltimore               38.0            75.0                 NaN
# 1    chicago               14.0            68.0                21.0
# 2   new york               21.0            65.0                14.0
# 3    orlando               35.0            71.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second  tempsum
# 0              NaN      NaN
# 1             65.0     35.0
# 2             68.0     35.0
# 3              NaN      NaN
# 4             71.0      NaN

# %%
df3[ df3.tempsum.isnull() == False]
# Out:
#        city  temperature_first  humidity_first  temperature_second  \
# 1   chicago               14.0            68.0                21.0
# 2  new york               21.0            65.0                14.0
#
#    humidity_second  tempsum
# 1             65.0     35.0
# 2             68.0     35.0

# %%
import numpy as np

# %%
df4 = df3.copy()
df4["temp sum"] = df4["temperature_first"] + df4["temperature_second"]
df4[ df4["temp sum"].isna() == False]
# Out:
#        city  temperature_first  humidity_first  temperature_second  \
# 1   chicago               14.0            68.0                21.0
# 2  new york               21.0            65.0                14.0
#
#    humidity_second  tempsum  temp sum
# 1             65.0     35.0      35.0
# 2             68.0     35.0      35.0

# %%
df3= pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature_x  humidity_x  temperature_y  humidity_y
# 0  baltimore           38.0        75.0            NaN         NaN
# 1    chicago           14.0        68.0           21.0        65.0
# 2   new york           21.0        65.0           14.0        68.0
# 3    orlando           35.0        71.0            NaN         NaN
# 4  san diego            NaN         NaN           35.0        71.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   city           5 non-null      object
#  1   temperature_x  4 non-null      float64
#  2   humidity_x     4 non-null      float64
#  3   temperature_y  3 non-null      float64
#  4   humidity_y     3 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 328.0+ bytes

# %% [markdown]
# ## <font>join</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1.set_index('city',inplace=True)
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2.set_index('city',inplace=True)
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df1.join(df2)
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75

# %%
combined_dfs = df1.join(df2)
combined_dfs
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75

# %%
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
pd.read_sql()
pd.read_sql_query()
pd.read_table()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/2336497031.py in <module>
# ----> 1 pd.read_sql()
#       2 pd.read_sql_query()
#       3 pd.read_table()
#
# TypeError: read_sql() missing 2 required positional arguments: 'sql' and 'con'

# %% [markdown]
# <h4>Pivot basics</h4>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df.T
# Out:
#                     0         1         2         3         4         5  \
# date         5/1/2017  5/2/2017  5/3/2017  5/1/2017  5/2/2017  5/3/2017
# city         new york  new york  new york    mumbai    mumbai    mumbai
# temperature        65        66        68        75        78        82
# humidity           56        58        60        80        83        85
#
#                     6         7         8
# date         5/1/2017  5/2/2017  5/3/2017
# city          beijing   beijing   beijing
# temperature        80        77        79
# humidity           26        30        35

# %%
df.pivot(index='city',columns='date')["temperature"]
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         80        77        79
# mumbai          75        78        82
# new york        65        66        68

# %%
df.pivot(index='city',columns='date')["temperature"].to_csv("pivot.csv")

# %%
df.pivot(index='city',columns='date', values="humidity") # return a dataframe
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index='date',columns='city').to_csv("pivotCity.csv")

# %%
df.pivot(index='humidity',columns='city')
# Out:
#               date                     temperature
# city       beijing    mumbai  new york     beijing mumbai new york
# humidity
# 26        5/1/2017       NaN       NaN        80.0    NaN      NaN
# 30        5/2/2017       NaN       NaN        77.0    NaN      NaN
# 35        5/3/2017       NaN       NaN        79.0    NaN      NaN
# 56             NaN       NaN  5/1/2017         NaN    NaN     65.0
# 58             NaN       NaN  5/2/2017         NaN    NaN     66.0
# 60             NaN       NaN  5/3/2017         NaN    NaN     68.0
# 80             NaN  5/1/2017       NaN         NaN   75.0      NaN
# 83             NaN  5/2/2017       NaN         NaN   78.0      NaN
# 85             NaN  5/3/2017       NaN         NaN   82.0      NaN

# %% [markdown]
# ## <h4>Pivot Table</h4>

# %%
df = pd.read_csv("data/weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# <h2>Margins</h2>

# %%
df.pivot_table(index="city",columns="date", aggfunc="sum")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date",aggfunc="sum")["temperature"]
# Out:
# date      5/1/2017  5/2/2017
# city
# mumbai         153       162
# new york       126       142

# %%
pd.crosstab(df.city,df.date, values= df.temperature , aggfunc="sum")
# Out:
# date      5/1/2017  5/2/2017
# city
# mumbai         153       162
# new york       126       142

# %%
pd.crosstab(df.city,df.date, values=df.humidity , aggfunc="sum")
# Out:
# date      5/1/2017  5/2/2017
# city
# mumbai         163       111
# new york       110       122

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_42958/225491910.py:1: FutureWarning: The provided callable <function sum at 0x7f8f60987af0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date",aggfunc=np.sum)
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)[["temperature"]]
# Out:
#          temperature
# date        5/1/2017 5/2/2017
# city
# mumbai           153      162
# new york         126      142

# %%
df.pivot_table(index="city",columns="date",aggfunc= "sum")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date", margins=True,aggfunc="sum")
# Out:
#          humidity               temperature
# date     5/1/2017 5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)["humidity"]
# Out:
# date      5/1/2017  5/2/2017
# city
# mumbai         163       111
# new york       110       122

# %% [markdown]
# <h4> Grouper in pivot table </h4>

# %%
df = pd.read_csv("data/weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
print(type(df["date"][0]))
df['date'] = pd.to_datetime(df['date'])
print(type(df["date"][0]))
# Out:
# <class 'str'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
type(df["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index=pd.Grouper(freq='W',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-07  56.666667   65.333333
# 2017-12-03  51.000000   27.666667

# %%
df.pivot_table(index=pd.Grouper(freq='W',key='date'),columns='city', aggfunc="sum")
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-05-07      170         196
# 2017-12-03      153          83

# %%
df.pivot_table(index=pd.Grouper(freq='W',key='date'),columns='city', aggfunc="sum")
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-05-07      170         196
# 2017-12-03      153          83

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city' , aggfunc= np.sum)
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-05-31      170         196
# 2017-12-31      153          83

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-12-31  53.833333        46.5

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-12-31      323         279

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-12-31      323         279

# %% [markdown]
# ### Melt

# %%
import pandas as pd
df = pd.read_csv("data/weathers.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df[["day", "chicago"]]
# Out:
#          day  chicago
# 0     Monday       32
# 1    Tuesday       30
# 2  Wednesday       28
# 3   Thursday       22
# 4     Friday       30
# 5   Saturday       20
# 6     Sunday       25

# %%
df[["day", "berlin"]]
# Out:
#          day  berlin
# 0     Monday      41
# 1    Tuesday      43
# 2  Wednesday      45
# 3   Thursday      38
# 4     Friday      30
# 5   Saturday      45
# 6     Sunday      47

# %%
melted = pd.melt(df, id_vars=["day"], var_name='city', value_name='temprature')
melted
# Out:
#           day     city  temprature
# 0      Monday  chicago          32
# 1     Tuesday  chicago          30
# 2   Wednesday  chicago          28
# 3    Thursday  chicago          22
# 4      Friday  chicago          30
# 5    Saturday  chicago          20
# 6      Sunday  chicago          25
# 7      Monday  chennai          75
# 8     Tuesday  chennai          77
# 9   Wednesday  chennai          75
# 10   Thursday  chennai          82
# 11     Friday  chennai          83
# 12   Saturday  chennai          81
# 13     Sunday  chennai          77
# 14     Monday   berlin          41
# 15    Tuesday   berlin          43
# 16  Wednesday   berlin          45
# 17   Thursday   berlin          38
# 18     Friday   berlin          30
# 19   Saturday   berlin          45
# 20     Sunday   berlin          47

# %%
city = melted [ melted["city"] == "berlin" ]

# %%
city
# Out:
#           day    city  temprature
# 14     Monday  berlin          41
# 15    Tuesday  berlin          43
# 16  Wednesday  berlin          45
# 17   Thursday  berlin          38
# 18     Friday  berlin          30
# 19   Saturday  berlin          45
# 20     Sunday  berlin          47

# %%
city = city.drop("city", axis=1)
city
# Out:
#           day  temprature
# 14     Monday          41
# 15    Tuesday          43
# 16  Wednesday          45
# 17   Thursday          38
# 18     Friday          30
# 19   Saturday          45
# 20     Sunday          47

# %%
city.rename({"temprature" : "temprature (berlin)" },axis=1 , inplace=True)

# %%
city
# Out:
#           day  temprature (berlin)
# 14     Monday                   41
# 15    Tuesday                   43
# 16  Wednesday                   45
# 17   Thursday                   38
# 18     Friday                   30
# 19   Saturday                   45
# 20     Sunday                   47

# %% [markdown]
# ### Reshape dataframe using stack/unstack

# %%
df = pd.read_excel("data/stocks.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df["Price"]
# Out:
#    Facebook  Google  Microsoft
# 0       155     955         66
# 1       150     987         69
# 2       153     963         62
# 3       155    1000         61
# 4       156    1012         66

# %%
df["Price"][["Facebook"]]
# Out:
#    Facebook
# 0       155
# 1       150
# 2       153
# 3       155
# 4       156

# %%
df["Price to earnings ratio (P/E)"]
# Out:
#    Facebook  Google  Microsoft
# 0     37.10    32.0      30.31
# 1     36.98    31.3      30.56
# 2     36.78    31.7      30.46
# 3     36.11    31.2      30.11
# 4     37.07    30.0      31.00

# %%
newdf = df.copy()
newdf
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack(level=0)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
df_stacked=df.stack()
df_stacked
# Out:
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
#   Microsoft                NaT    69.0                          30.56
# 2 Company           2017-06-07     NaN                            NaN
#   Facebook                 NaT   153.0                          36.78
#   Google                   NaT   963.0                          31.70
#   Microsoft                NaT    62.0                          30.46
# ...

# %%
df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                             Price                   \
#              Company Facebook Google Microsoft Company Facebook  Google
# 0         2017-06-05      NaT    NaT       NaT     NaN    155.0   955.0
# 1         2017-06-06      NaT    NaT       NaT     NaN    150.0   987.0
# 2         2017-06-07      NaT    NaT       NaT     NaN    153.0   963.0
# 3         2017-06-08      NaT    NaT       NaT     NaN    155.0  1000.0
# 4         2017-06-09      NaT    NaT       NaT     NaN    156.0  1012.0
#
#             Price to earnings ratio (P/E)
#   Microsoft                       Company Facebook Google Microsoft
# 0      66.0                           NaN    37.10   32.0     30.31
# 1      69.0                           NaN    36.98   31.3     30.56
# 2      62.0                           NaN    36.78   31.7     30.46
# 3      61.0                           NaN    36.11   31.2     30.11
# 4      66.0                           NaN    37.07   30.0     31.00

# %%
df_stacked[df_stacked.columns[0]]
# Out:
# 0  Company     2017-06-05
#    Facebook           NaT
#    Google             NaT
#    Microsoft          NaT
# 1  Company     2017-06-06
#    Facebook           NaT
#    Google             NaT
#    Microsoft          NaT
# 2  Company     2017-06-07
#    Facebook           NaT
#    Google             NaT
#    Microsoft          NaT
# 3  Company     2017-06-08
#    Facebook           NaT
#    Google             NaT
#    Microsoft          NaT
# 4  Company     2017-06-09
#    Facebook           NaT
#    Google             NaT
#    Microsoft          NaT
# Name: Unnamed: 0_level_0, dtype: datetime64[ns]

# %% [markdown]
# <h1 style="color:blue">3 levels of column headers</h1>

# %%
df2 = pd.read_excel("data/stocks_3_levels.xlsx",header=[0,1,2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df2["Price Ratios"]
# Out:
#      Price                  Price to earnings ratio (P/E)
#   Facebook Google Microsoft                      Facebook Google Microsoft
# 0      155    955        66                         37.10   32.0     30.31
# 1      150    987        69                         36.98   31.3     30.56
# 2      153    963        62                         36.78   31.7     30.46
# 3      155   1000        61                         36.11   31.2     30.11
# 4      156   1012        66                         37.07   30.0     31.00

# %%
df2["Income Statement"]
# Out:
#   Net Sales                  Net Profit
#    Facebook Google Microsoft   Facebook Google Microsoft
# 0       2.6     20     18.70       0.80   5.43      4.56
# 1       3.1     22     21.30       0.97   5.89      5.10
# 2       4.3     24     21.45       1.20   6.10      5.43
# 3       6.7     26     21.88       1.67   6.50      5.89
# 4       8.1     31     22.34       2.03   6.40      6.09

# %%
df2.stack()
# Out:
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
#   Google                   NaN        987.0                         31.30
#   Microsoft                NaN         69.0                         30.56
# 2 Company              Q3 2016          NaN                           NaN
#   Facebook                 NaN        153.0                         36.78
#   Google                   NaN        963.0                         31.70
# ...

# %%
df2.stack(level=0)
# Out:
#                      Unnamed: 0_level_1    Price                    \
#                                 Company Facebook  Google Microsoft
# 0 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    155.0   955.0      66.0
#   Unnamed: 0_level_0            Q1 2016      NaN     NaN       NaN
# 1 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    150.0   987.0      69.0
#   Unnamed: 0_level_0            Q2 2016      NaN     NaN       NaN
# 2 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    153.0   963.0      62.0
#   Unnamed: 0_level_0            Q3 2016      NaN     NaN       NaN
# 3 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    155.0  1000.0      61.0
#   Unnamed: 0_level_0            Q4 2016      NaN     NaN       NaN
# ...

# %%
df2.stack(level=1)
# Out:
#                                 Unnamed: 0_level_0 Price Ratios          \
#                                            Company     Facebook  Google
# 0 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
#   Price                                        NaN       155.00   955.0
#   Price to earnings ratio (P/E)                NaN        37.10    32.0
#   Unnamed: 0_level_1                       Q1 2016          NaN     NaN
# 1 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
#   Price                                        NaN       150.00   987.0
#   Price to earnings ratio (P/E)                NaN        36.98    31.3
#   Unnamed: 0_level_1                       Q2 2016          NaN     NaN
# 2 Net Profit                                   NaN          NaN     NaN
# ...

# %%
df2["Price Ratios"]["Price"]
# Out:
#    Facebook  Google  Microsoft
# 0       155     955         66
# 1       150     987         69
# 2       153     963         62
# 3       155    1000         61
# 4       156    1012         66

# %%
df2["Price Ratios"]["Price to earnings ratio (P/E)"]
# Out:
#    Facebook  Google  Microsoft
# 0     37.10    32.0      30.31
# 1     36.98    31.3      30.56
# 2     36.78    31.7      30.46
# 3     36.11    31.2      30.11
# 4     37.07    30.0      31.00

# %%
df2["Income Statement"]
# Out:
#   Net Sales                  Net Profit
#    Facebook Google Microsoft   Facebook Google Microsoft
# 0       2.6     20     18.70       0.80   5.43      4.56
# 1       3.1     22     21.30       0.97   5.89      5.10
# 2       4.3     24     21.45       1.20   6.10      5.43
# 3       6.7     26     21.88       1.67   6.50      5.89
# 4       8.1     31     22.34       2.03   6.40      6.09

# %%
df2["Income Statement"]["Net Sales"]
# Out:
#    Facebook  Google  Microsoft
# 0       2.6      20      18.70
# 1       3.1      22      21.30
# 2       4.3      24      21.45
# 3       6.7      26      21.88
# 4       8.1      31      22.34

# %%
df2["Income Statement"]["Net Profit"]
# Out:
#    Facebook  Google  Microsoft
# 0      0.80    5.43       4.56
# 1      0.97    5.89       5.10
# 2      1.20    6.10       5.43
# 3      1.67    6.50       5.89
# 4      2.03    6.40       6.09

# %% [markdown]
# ## Crosstab

# %%
df = pd.read_excel("data/survey.xls")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Nationality,df.Handedness).T
# Out:
# Nationality  Bangadesh  China  India  USA
# Handedness
# Left                 2      2      2    1
# Right                0      1      1    3

# %%
# similar code 
countries = df.Nationality.value_counts().index.to_list()
for i in countries:
    print(i)
    print(len(df [(df.Nationality == i) & (df.Handedness == "Right")]))
    print(len(df [(df.Nationality == i) & (df.Handedness == "Left")]))
    print()
# Out:
# USA
# 3
# 1
#
# India
# 1
# 2
#
# China
# 1
# 2
#
# Bangadesh
# 0
# 2

# %%
pd.crosstab(df.Handedness,df.Nationality)
# Out:
# Nationality  Bangadesh  China  India  USA
# Handedness
# Left                 2      2      2    1
# Right                0      1      1    3

# %%
pd.crosstab(df.Sex,df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %% [markdown]
# <h2 style="color:purple">Margins</h2>

# %%
pd.crosstab(df.Sex,df.Handedness, margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %% [markdown]
# <h2 style="color:purple">Multi Index Column and Rows</h2>

# %%
pd.crosstab(df.Sex, [df.Handedness,df.Nationality])
# Out:
# Handedness       Left                 Right
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2
# Male                1     1     2   1     0     1   1

# %%
pd.crosstab(df.Sex, [df.Handedness,df.Nationality], margins=True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %%
pd.crosstab([df.Nationality, df.Sex], [df.Handedness])
# Out:
# Handedness          Left  Right
# Nationality Sex
# Bangadesh   Female     1      0
#             Male       1      0
# China       Female     1      1
#             Male       1      0
# India       Male       2      1
# USA         Female     0      2
#             Male       1      1

# %%
pd.crosstab([df.Nationality, df.Sex], [df.Handedness], margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
pd.crosstab([df.Sex, df.Nationality], [df.Handedness], margins=True)
# Out:
# Handedness          Left  Right  All
# Sex    Nationality
# Female Bangadesh       1      0    1
#        China           1      1    2
#        USA             0      2    2
# Male   Bangadesh       1      0    1
#        China           1      0    1
#        India           2      1    3
#        USA             1      1    2
# All                    7      5   12

# %% [markdown]
# <h2 style="color:purple">Normalize</h2>

# %%
pd.crosstab(df.Sex, df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
pd.crosstab(df.Sex, df.Handedness, normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %% [markdown]
# <h2 style="color:purple">Aggfunc and Values</h2>

# %%
import numpy as np
pd.crosstab(df.Sex, df.Handedness )
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
import numpy as np
pd.crosstab(df.Sex, df.Handedness, values=df.Age, aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
pd.crosstab(df.Sex, df.Handedness, values=df.Age, aggfunc=np.sum)
# Out:
# Handedness  Left  Right
# Sex
# Female        89     93
# Male         156     56

# %%
import numpy as np
pd.crosstab(df.Sex, df.Handedness, values=df.Age, aggfunc="sum")
# Out:
# Handedness  Left  Right
# Sex
# Female        89     93
# Male         156     56

# %%
import numpy as np
pd.crosstab(df.Nationality, df.Handedness, values=df.Age, aggfunc=np.average)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh    28.0    NaN
# China        50.5   52.0
# India        33.0   37.0
# USA          22.0   20.0

# %%
pd.crosstab([df.Nationality, df.Sex], df.Handedness, values=df.Age, aggfunc=np.average)
# Out:
# Handedness          Left  Right
# Nationality Sex
# Bangadesh   Female  31.0    NaN
#             Male    25.0    NaN
# China       Female  58.0   52.0
#             Male    43.0    NaN
# India       Male    33.0   37.0
# USA         Female   NaN   20.5
#             Male    22.0   19.0

# %%
import numpy as np
pd.crosstab(df.Nationality, df.Handedness, values=df.Age, aggfunc=np.sum)
# Out:
# Handedness    Left  Right
# Nationality
# Bangadesh     56.0    NaN
# China        101.0   52.0
# India         66.0   37.0
# USA           22.0   60.0

# %%
import numpy as np
pd.crosstab(df.Nationality, df.Sex, values= df.Age, aggfunc= np.sum)
# Out:
# Sex          Female   Male
# Nationality
# Bangadesh      31.0   25.0
# China         110.0   43.0
# India           NaN  103.0
# USA            41.0   41.0

# %%
import numpy as np
pd.crosstab(df.Nationality, df.Sex)
# Out:
# Sex          Female  Male
# Nationality
# Bangadesh         1     1
# China             2     1
# India             0     3
# USA               2     2

# %%
import numpy as np
pd.crosstab(df.Nationality, df.Sex, values= df.Age, aggfunc= "sum")
# Out:
# Sex          Female   Male
# Nationality
# Bangadesh      31.0   25.0
# China         110.0   43.0
# India           NaN  103.0
# USA            41.0   41.0

# %% [markdown]
# ### Time Series Analysis
# ### Holdidays

# %%
import pandas as pd

# %%
df = pd.read_csv("data/aapl_no_dates.csv")
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  144.88  145.30  143.10  143.50  14277848
# 1  143.69  144.79  142.72  144.09  21569557
# 2  143.02  143.50  142.41  142.73  24128782
# 3  142.90  144.75  142.90  144.18  19201712
# 4  144.11  145.95  143.37  145.06  21090636

# %%
df.shape
# Out:
# (14, 5)

# %%
rng = pd.date_range(start="7/1/2017", end="7/14/2017", freq='D') # business days
rng
# Out:
# DatetimeIndex(['2017-07-01', '2017-07-02', '2017-07-03', '2017-07-04',
#                '2017-07-05', '2017-07-06', '2017-07-07', '2017-07-08',
#                '2017-07-09', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng = pd.date_range(start="7/1/2017", end="7/21/2017", freq='B') # business days
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# **Using 'B' frequency is not going to help because 4th July was holiday and 'B' is not taking that into account.
# It only accounts for weekends**

# %% [markdown]
# <h3>Using CustomBusinessDay to generate US holidays calendar frequency</h3>

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

us_cal = CustomBusinessDay(calendar = USFederalHolidayCalendar())

rng = pd.date_range(start="7/1/2017",end="7/23/2017", freq=us_cal)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng,inplace=True)
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  144.11  145.95  143.37  145.06  21090636

# %% [markdown]
# **You can define your own calendar using AbstractHolidayCalendar as shown below. USFederalHolidayCalendar is the only calendar available in pandas library and it serves as an example for those who want to write their own custom calendars. Here is the link for USFederalHolidayCalendar implementation** https://github.com/pandas-dev/pandas/blob/master/pandas/tseries/holiday.py

# %% [markdown]
# <h3>Abstract Holiday Calendar</h3>

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=3, day=31),# observance=nearest_workday),
    ]
my_bday = CustomBusinessDay(calendar = myCalendar())
pd.date_range('3/25/2017','4/30/2017',freq = my_bday )
# Out:
# DatetimeIndex(['2017-03-27', '2017-03-28', '2017-03-29', '2017-03-30',
#                '2017-04-03', '2017-04-04', '2017-04-05', '2017-04-06',
#                '2017-04-07', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14', '2017-04-17', '2017-04-18',
#                '2017-04-19', '2017-04-20', '2017-04-21', '2017-04-24',
#                '2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# <h3>Custom Business Days</h3>

# %% [markdown]
# **Weekend in egypt is Friday and Saturday. Sunday is just a normal weekday and you can handle this custom week schedule using
# CystomBysinessDay with weekmask as shown below**

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"

b = CustomBusinessDay( weekmask = egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# **You can also add holidays to this custom business day frequency**

# %%
b = CustomBusinessDay(holidays=['2017-07-04', '2017-07-10'], weekmask=egypt_weekdays)
pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-09', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-23', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# **Mathematical operations on date object using custom business day**

# %%
from datetime import datetime
dt = datetime(2017,7,9)
dt
# Out:
# datetime.datetime(2017, 7, 9, 0, 0)

# %%
dt + 1*b
# Out:
# Timestamp('2017-07-10 00:00:00')

# %% [markdown]
# <h3 style="color:purple">Benefits of having DatetimeIndex</h3>

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df["2016-06-01":"2016-06-10"].Close.mean()
# Out:
# nan

# %%
import pandas as pd
df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_97814/4275520726.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
#       3 df.head(2)
#
# ...

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# <h3 style="color:purple">What is DatetimeIndex? Benefits of it</h3>

# %% [markdown]
# <h4> (1) Partial Date Index: Select Specific Months Data</h4>

# %%
df['2017-06-30']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df["2017-01"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# ...

# %%
df['2017-06'].head()
# Out:
# <ipython-input-4-7cdceb9856e4>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-06'].head()
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361

# %% [markdown]
# <h4>Average price of aapl's stock in June, 2017</h4>

# %%
df['2017-06'].Close.mean()
# Out:
# <ipython-input-5-8e25964a0c31>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-06'].Close.mean()
# 147.8313636363636

# %%
df['2017'].head(2)
# Out:
# <ipython-input-6-09b5e2045e92>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017'].head(2)
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %% [markdown]
# <h4>(2) Select Date Range</h4>

# %%
df['2017-01-08':'2017-01-03']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
df['2017-01']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# ...

# %% [markdown]
# <h3 style="color:purple">Resampling</h3>

# %%
df['Close'].resample('M').mean().head()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# Freq: M, Name: Close, dtype: float64

# %%
df['2016-07']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-07-29  104.19  104.55  103.68  104.21  27733688
# 2016-07-28  102.83  104.45  102.82  104.34  39869839
# 2016-07-27  104.26  104.35  102.75  102.95  92344820
# 2016-07-26   96.82   97.97   96.42   96.67  56239822
# 2016-07-25   98.25   98.84   96.92   97.34  40382921
# 2016-07-22   99.26   99.30   98.31   98.66  28313669
# 2016-07-21   99.83  101.00   99.13   99.43  32702028
# 2016-07-20  100.00  100.46   99.74   99.96  26275968
# 2016-07-19   99.56  100.00   99.34   99.87  23779924
# 2016-07-18   98.70  100.13   98.60   99.83  36493867
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945

# %%
# %matplotlib inline
df['Close'].plot()

# %%
df['Close'].resample('M').mean().plot(kind='bar')
