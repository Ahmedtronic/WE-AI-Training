# %%
import pandas as pd

# %%
# pip , conda, uv, mamba, ...

# %%
data = pd.read_csv("customer_shopping_data.csv")
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
# Exploration

# %%
data.shape
# Out:
# (99457, 10)

# %%
data.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
data["gender"]
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object

# %%
data[["gender"]]
# Out:
#        gender
# 0      Female
# 1        Male
# 2        Male
# 3      Female
# 4      Female
# ...       ...
# 99452  Female
# 99453    Male
# 99454    Male
# 99455    Male
# 99456  Female
#
# [99457 rows x 1 columns]

# %%
data.gender
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
data.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
data.head(3)
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity

# %%
data.tail(3)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
data[ 0 : 3 ]
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity

# %%
data[ 0 : 1 ]
# Out:
#   invoice_no customer_id  gender  age  category  quantity   price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.4
#
#   payment_method invoice_date shopping_mall
# 0    Credit Card     5/8/2022        Kanyon

# %%
type(data.gender)
# Out:
# pandas.core.series.Series

# %%
data.gender
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object

# %%
data.gender.values
# Out:
# array(['Female', 'Male', 'Male', ..., 'Male', 'Male', 'Female'],
#       dtype=object)

# %%
type(data.gender.values)
# Out:
# numpy.ndarray

# %%
data.head(30)
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 1     I317333     C111565    Male   21            Shoes         3  1800.51
# 2     I127801     C266599    Male   20         Clothing         1   300.08
# 3     I173702     C988172  Female   66            Shoes         5  3000.85
# 4     I337046     C189076  Female   53            Books         4    60.60
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 7     I293112     C176086  Female   32         Clothing         2   600.16
# 8     I293455     C159642    Male   69         Clothing         3   900.24
# 9     I326945     C283361  Female   60         Clothing         2   600.16
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# ...

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.age
# Out:
# 0        28
# 1        21
# 2        20
# 3        66
# 4        53
#          ..
# 99452    45
# 99453    27
# 99454    63
# 99455    56
# 99456    36
# Name: age, Length: 99457, dtype: int64

# %%
data.age.min()
# Out:
# 18

# %%
data.age.max()
# Out:
# 69

# %%
data.age.sum()
# Out:
# 4319128

# %%
data.age.mean()
# Out:
# 43.42708909377922

# %%
data.age.median()
# Out:
# 43.0

# %%
data.age.mode()
# Out:
# 0    37
# Name: age, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.quantity.max()
# Out:
# 5

# %%
data.quantity.dtype
# Out:
# dtype('int64')

# %%
data.quantity = data.quantity.astype("int8")

# %%
data.quantity
# Out:
# 0        5
# 1        3
# 2        1
# 3        5
# 4        4
#         ..
# 99452    5
# 99453    2
# 99454    2
# 99455    4
# 99456    3
# Name: quantity, Length: 99457, dtype: int8

# %%
data.quantity.dtype
# Out:
# dtype('int8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int8
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(1), int8(1), object(7)
# memory usage: 6.9+ MB

# %%
data.head(10)
# Out:
#   invoice_no customer_id  gender  age   category  quantity    price  \
# 0    I138884     C241288  Female   28   Clothing         5  1500.40
# 1    I317333     C111565    Male   21      Shoes         3  1800.51
# 2    I127801     C266599    Male   20   Clothing         1   300.08
# 3    I173702     C988172  Female   66      Shoes         5  3000.85
# 4    I337046     C189076  Female   53      Books         4    60.60
# 5    I227836     C657758  Female   28   Clothing         5  1500.40
# 6    I121056     C151197  Female   49  Cosmetics         1    40.66
# 7    I293112     C176086  Female   32   Clothing         2   600.16
# 8    I293455     C159642    Male   69   Clothing         3   900.24
# 9    I326945     C283361  Female   60   Clothing         2   600.16
#
#   payment_method invoice_date     shopping_mall
# 0    Credit Card     5/8/2022            Kanyon
# 1     Debit Card   12/12/2021    Forum Istanbul
# 2           Cash    9/11/2021         Metrocity
# ...

# %%
data[10: 11]
# Out:
#    invoice_no customer_id  gender  age         category  quantity  price  \
# 10    I306368     C240286  Female   36  Food & Beverage         2  10.46
#
#    payment_method invoice_date shopping_mall
# 10           Cash   25/12/2022     Metrocity

# %%
data.loc[10]
# Out:
# invoice_no                I306368
# customer_id               C240286
# gender                     Female
# age                            36
# category          Food & Beverage
# quantity                        2
# price                       10.46
# payment_method               Cash
# invoice_date           25/12/2022
# shopping_mall           Metrocity
# Name: 10, dtype: object

# %%
data.loc[3]["category"]
# Out:
# 'Shoes'

# %%
data.loc[3][4]
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_10548/2889319662.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.loc[3][4]
# 'Shoes'

# %%
data.loc[3, 4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data.loc[3, 4]
#
# ...

# %%
data.iloc[3, 4]
# Out:
# 'Shoes'

# %%
# select * from data where gender = Male; 

data [ data.gender == "Male"]
# Out:
#       invoice_no customer_id gender  age         category  quantity    price  \
# 1        I317333     C111565   Male   21            Shoes         3  1800.51
# 2        I127801     C266599   Male   20         Clothing         1   300.08
# 8        I293455     C159642   Male   69         Clothing         3   900.24
# 13       I179802     C312861   Male   25         Clothing         2   600.16
# 15       I688768     C362288   Male   24            Shoes         5  3000.85
# ...          ...         ...    ...  ...              ...       ...      ...
# 99449    I134399     C953724   Male   65         Clothing         1   300.08
# 99451    I675411     C513603   Male   50             Toys         5   179.20
# 99453    I325143     C569580   Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292   Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631   Male   56       Technology         4  4200.00
#
# ...

# %%
data [ data.age == 20  ]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 191      I156233     C161285  Female   20         Clothing         1   300.08
# 220      I798213     C662958  Female   20            Shoes         3  1800.51
# 239      I204147     C252021  Female   20            Shoes         3  1800.51
# 290      I281274     C130479    Male   20         Clothing         1   300.08
# ...          ...         ...     ...  ...              ...       ...      ...
# 99036    I173503     C107419    Male   20             Toys         2    71.68
# 99045    I235989     C307974    Male   20         Clothing         3   900.24
# 99193    I326396     C293279  Female   20            Shoes         2  1200.34
# 99299    I711950     C212383  Female   20  Food & Beverage         1     5.23
# 99309    I337751     C253676  Female   20         Clothing         4  1200.32
#
# ...

# %%
data [ data.category == "Clothing"]
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 0        I138884     C241288  Female   28  Clothing         5  1500.40
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 5        I227836     C657758  Female   28  Clothing         5  1500.40
# 7        I293112     C176086  Female   32  Clothing         2   600.16
# 8        I293455     C159642    Male   69  Clothing         3   900.24
# ...          ...         ...     ...  ...       ...       ...      ...
# 99435    I141871     C298790  Female   62  Clothing         3   900.24
# 99436    I579905     C265057  Female   57  Clothing         5  1500.40
# 99440    I887161     C137631  Female   58  Clothing         1   300.08
# 99442    I105959     C131810  Female   45  Clothing         4  1200.32
# 99449    I134399     C953724    Male   65  Clothing         1   300.08
#
#       payment_method invoice_date      shopping_mall
# 0        Credit Card     5/8/2022             Kanyon
# ...

# %%
data.age.max()
# Out:
# 69

# %%
data [ data.age == data.age.max() ]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 8        I293455     C159642    Male   69         Clothing         3   900.24
# 77       I115870     C135790  Female   69            Shoes         4  2400.68
# 211      I226172     C171154  Female   69            Shoes         1   600.17
# 212      I737630     C848969    Male   69         Clothing         5  1500.40
# 282      I263818     C336232    Male   69         Souvenir         4    46.92
# ...          ...         ...     ...  ...              ...       ...      ...
# 98796    I146016     C203641  Female   69       Technology         2  2100.00
# 98839    I214432     C685875    Male   69             Toys         4   143.36
# 99007    I173132     C955663  Female   69         Clothing         3   900.24
# 99043    I482625     C274732  Female   69        Cosmetics         1    40.66
# 99321    I234667     C321665    Male   69  Food & Beverage         1     5.23
#
# ...

# %%
data [ data.age.between(30,40) ]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 7        I293112     C176086  Female   32         Clothing         2   600.16
# 10       I306368     C240286  Female   36  Food & Beverage         2    10.46
# 32       I768348     C176727  Female   32            Shoes         3  1800.51
# 43       I826174     C607615  Female   40            Shoes         4  2400.68
# 59       I335713     C158837  Female   36            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99441    I203187     C235554    Male   38  Food & Beverage         4    20.92
# 99445    I750456     C270290  Female   35  Food & Beverage         5    26.15
# 99446    I327966     C107209  Female   32  Food & Beverage         1     5.23
# 99447    I281214     C288090  Female   37             Toys         3   107.52
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data["category"][:5]
# Out:
# 0    Clothing
# 1       Shoes
# 2    Clothing
# 3       Shoes
# 4       Books
# Name: category, dtype: object

# %%
data[data.age == 20]["customer_id"]
# Out:
# 2        C266599
# 191      C161285
# 220      C662958
# 239      C252021
# 290      C130479
#           ...
# 99036    C107419
# 99045    C307974
# 99193    C293279
# 99299    C212383
# 99309    C253676
# Name: customer_id, Length: 1844, dtype: object

# %%
data [["gender", "age"]]
# Out:
#        gender  age
# 0      Female   28
# 1        Male   21
# 2        Male   20
# 3      Female   66
# 4      Female   53
# ...       ...  ...
# 99452  Female   45
# 99453    Male   27
# 99454    Male   63
# 99455    Male   56
# 99456  Female   36
#
# [99457 rows x 2 columns]

# %%
data[ data.price > 1500]
# Out:
#       invoice_no customer_id  gender  age    category  quantity    price  \
# 0        I138884     C241288  Female   28    Clothing         5  1500.40
# 1        I317333     C111565    Male   21       Shoes         3  1800.51
# 3        I173702     C988172  Female   66       Shoes         5  3000.85
# 5        I227836     C657758  Female   28    Clothing         5  1500.40
# 15       I688768     C362288    Male   24       Shoes         5  3000.85
# ...          ...         ...     ...  ...         ...       ...      ...
# 99424    I549710     C541824  Female   34  Technology         3  3150.00
# 99430    I336082     C316368    Male   26    Clothing         5  1500.40
# 99436    I579905     C265057  Female   57    Clothing         5  1500.40
# 99448    I332105     C231387  Female   65       Shoes         4  2400.68
# 99455    I702964     C800631    Male   56  Technology         4  4200.00
#
#       payment_method invoice_date     shopping_mall
# ...

# %%
data[ data.price > 1500].shape[(0)]
# Out:
# 16996

# %%
data.gender
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object

# %%
data.shopping_mall
# Out:
# 0                  Kanyon
# 1          Forum Istanbul
# 2               Metrocity
# 3            Metropol AVM
# 4                  Kanyon
#                ...
# 99452              Kanyon
# 99453      Forum Istanbul
# 99454           Metrocity
# 99455        Istinye Park
# 99456    Mall of Istanbul
# Name: shopping_mall, Length: 99457, dtype: object

# %%
data.shopping_mall.max()
# Out:
# 'Zorlu Center'

# %%
data.shopping_mall.value_counts()
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
data.shopping_mall.value_counts()[0]
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_10548/3347848034.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.shopping_mall.value_counts()[0]
# 19943

# %%
data.shopping_mall.value_counts().idxmax()
# Out:
# 'Mall of Istanbul'

# %%
data.shopping_mall.value_counts().max()
# Out:
# 19943

# %%
data.isna().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
data.customer_id.value_counts()
# Out:
# customer_id
# C241288    1
# C116138    1
# C382765    1
# C285074    1
# C405356    1
#           ..
# C220083    1
# C286933    1
# C301304    1
# C214184    1
# C273973    1
# Name: count, Length: 99457, dtype: int64

# %%
data.customer_id.duplicated().sum()
# Out:
# 0

# %%
data.customer_id.duplicated().sum()
# Out:
# 0

# %%
data.quantity.value_counts()
# Out:
# quantity
# 3    20149
# 5    19990
# 2    19828
# 1    19767
# 4    19723
# Name: count, dtype: int64

# %%
data.payment_method.value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
data["invoice_date"].dtype
# Out:
# dtype('O')

# %%
data["date"] = pd.to_datetime(data.invoice_date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 data["date"] = pd.to_datetime(data.invoice_date)
#
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
data["total_amount"] = data.quantity * data.price 
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data["date"] = pd.to_datetime(data.invoice_date, dayfirst = True)
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int8
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
#  10  total_amount    99457 non-null  float64
#  11  date            99457 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), int8(1), object(7)
# memory usage: 8.4+ MB

# %%
data["day"] = data.date.dt.day
data["month"] = data.date.dt.month
data["year"] = data.date.dt.year
data["month/year"] = data.date.dt.to_period("M")
data["quarter"] = data.date.dt.quarter
data["week"] = data.date.dt.isocalendar().week

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data[ data.year == 2022]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# 6        I121056     C151197  Female   49        Cosmetics         1    40.66
# 10       I306368     C240286  Female   36  Food & Beverage         2    10.46
# 11       I139207     C191708  Female   29            Books         1    15.15
# ...          ...         ...     ...  ...              ...       ...      ...
# 99434    I186560     C117024  Female   39            Shoes         1   600.17
# 99435    I141871     C298790  Female   62         Clothing         3   900.24
# 99436    I579905     C265057  Female   57         Clothing         5  1500.40
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data[ data.month == 11]
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 2        I127801     C266599    Male   20   Clothing         1   300.08
# 8        I293455     C159642    Male   69   Clothing         3   900.24
# 13       I179802     C312861    Male   25   Clothing         2   600.16
# 15       I688768     C362288    Male   24      Shoes         5  3000.85
# 31       I331891     C501658    Male   23   Clothing         1   300.08
# ...          ...         ...     ...  ...        ...       ...      ...
# 99372    I134370     C524812  Female   22  Cosmetics         4   162.64
# 99385    I484380     C293542  Female   41   Clothing         4  1200.32
# 99421    I419578     C279804    Male   58      Books         3    45.45
# 99433    I403904     C142643    Male   28       Toys         1    35.84
# 99444    I131678     C119287    Male   24       Toys         1    35.84
#
#       payment_method invoice_date      shopping_mall  total_amount       date  \
# ...

# %%
data[ data.day == 1].price.sum()
# Out:
# 2252638.88

# %%
data[ data.year == 2022].price.sum()
# Out:
# 31372826.180000003

# %%
online_data = pd.read_csv("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")
online_data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
def extract_different_times( data , date_column ):
    data["day"] = data[date_column].dt.day
    data["month"] = data[date_column].dt.month
    data["year"] = data[date_column].dt.year
    data["month/year"] = data[date_column].dt.to_period("M")
    data["quarter"] = data[date_column].dt.quarter
    data["week"] = data[date_column].dt.isocalendar().week

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.drop( "customer_id" , axis = 1 )
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.drop( "customer_id" , axis = 1 , inplace = True )

# %%
data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data.rename( {"payment_method" : "payment method"} , axis = 1 )
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data.rename( {"payment_method" : "payment method"} , axis = 1, inplace = True  )
data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data.payment method
# Out:
#   Cell In[110], line 1
#     data.payment method
#                  ^
# SyntaxError: invalid syntax

# %%
data.gender
# Out:
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object

# %%
data["payment method"]
# Out:
# 0        Credit Card
# 1         Debit Card
# 2               Cash
# 3        Credit Card
# 4               Cash
#             ...
# 99452    Credit Card
# 99453           Cash
# 99454     Debit Card
# 99455           Cash
# 99456    Credit Card
# Name: payment method, Length: 99457, dtype: object

# %%
data.rename({"payment method" : "payment_method"} , axis = 1 , inplace = True )
data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data.drop_duplicates( inplace = True )

# %%
data.duplicated().sum()
# Out:
# 0

# %%
employees = {
    "name" : ["Ahmed", "Mohamed", "Ali"],
    "salaries" : [1000, 2000, 3000 ]
}

# %%
employees_df = pd.DataFrame(employees)
employees_df
# Out:
#       name  salaries
# 0    Ahmed      1000
# 1  Mohamed      2000
# 2      Ali      3000

# %%
type(employees_df)
# Out:
# pandas.core.frame.DataFrame

# %%
{ 
    "name" : "Ahmed"
} # map in C++ , json : js ``

# %%
new_data = pd.read_csv("customer_shopping_data.csv", header = None )
new_data
# Out:
# /var/folders/_r/3sb29fjj12d916yfxyrhd_gc0000gn/T/ipykernel_10548/2725181962.py:1: DtypeWarning: Columns (3,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_data = pd.read_csv("customer_shopping_data.csv", header = None )
#                 0            1       2    3                4         5  \
# 0      invoice_no  customer_id  gender  age         category  quantity
# 1         I138884      C241288  Female   28         Clothing         5
# 2         I317333      C111565    Male   21            Shoes         3
# 3         I127801      C266599    Male   20         Clothing         1
# 4         I173702      C988172  Female   66            Shoes         5
# ...           ...          ...     ...  ...              ...       ...
# 99453     I219422      C441542  Female   45         Souvenir         5
# 99454     I325143      C569580    Male   27  Food & Beverage         2
# 99455     I824010      C103292    Male   63  Food & Beverage         2
# ...

# %%
new_data = pd.read_csv("customer_shopping_data.csv", header = 1 )
new_data
# Out:
#        I138884  C241288  Female  28         Clothing  5   1500.4  Credit Card  \
# 0      I317333  C111565    Male  21            Shoes  3  1800.51   Debit Card
# 1      I127801  C266599    Male  20         Clothing  1   300.08         Cash
# 2      I173702  C988172  Female  66            Shoes  5  3000.85  Credit Card
# 3      I337046  C189076  Female  53            Books  4    60.60         Cash
# 4      I227836  C657758  Female  28         Clothing  5  1500.40  Credit Card
# ...        ...      ...     ...  ..              ... ..      ...          ...
# 99451  I219422  C441542  Female  45         Souvenir  5    58.65  Credit Card
# 99452  I325143  C569580    Male  27  Food & Beverage  2    10.46         Cash
# 99453  I824010  C103292    Male  63  Food & Beverage  2    10.46   Debit Card
# 99454  I702964  C800631    Male  56       Technology  4  4200.00         Cash
# 99455  I232867  C273973  Female  36         Souvenir  3    35.19  Credit Card
#
# ...

# %%
new_data = pd.read_csv("customer_shopping_data.csv", skiprows= 10 )
new_data
# Out:
#        I326945  C283361  Female  60         Clothing  2   600.16  Credit Card  \
# 0      I306368  C240286  Female  36  Food & Beverage  2    10.46         Cash
# 1      I139207  C191708  Female  29            Books  1    15.15  Credit Card
# 2      I640508  C225330  Female  67             Toys  4   143.36   Debit Card
# 3      I179802  C312861    Male  25         Clothing  2   600.16         Cash
# 4      I336189  C555402  Female  67         Clothing  2   600.16  Credit Card
# ...        ...      ...     ...  ..              ... ..      ...          ...
# 99442  I219422  C441542  Female  45         Souvenir  5    58.65  Credit Card
# 99443  I325143  C569580    Male  27  Food & Beverage  2    10.46         Cash
# 99444  I824010  C103292    Male  63  Food & Beverage  2    10.46   Debit Card
# 99445  I702964  C800631    Male  56       Technology  4  4200.00         Cash
# 99446  I232867  C273973  Female  36         Souvenir  3    35.19  Credit Card
#
# ...

# %%
new_data = pd.read_csv("customer_shopping_data.csv", nrows = 10  )
new_data
# Out:
#   invoice_no customer_id  gender  age   category  quantity    price  \
# 0    I138884     C241288  Female   28   Clothing         5  1500.40
# 1    I317333     C111565    Male   21      Shoes         3  1800.51
# 2    I127801     C266599    Male   20   Clothing         1   300.08
# 3    I173702     C988172  Female   66      Shoes         5  3000.85
# 4    I337046     C189076  Female   53      Books         4    60.60
# 5    I227836     C657758  Female   28   Clothing         5  1500.40
# 6    I121056     C151197  Female   49  Cosmetics         1    40.66
# 7    I293112     C176086  Female   32   Clothing         2   600.16
# 8    I293455     C159642    Male   69   Clothing         3   900.24
# 9    I326945     C283361  Female   60   Clothing         2   600.16
#
#   payment_method invoice_date     shopping_mall
# 0    Credit Card     5/8/2022            Kanyon
# 1     Debit Card   12/12/2021    Forum Istanbul
# 2           Cash    9/11/2021         Metrocity
# ...

# %%
new_data = pd.read_csv("customer_shopping_data.csv", nrows = 1000  )
new_data
# Out:
#     invoice_no customer_id  gender  age         category  quantity    price  \
# 0      I138884     C241288  Female   28         Clothing         5  1500.40
# 1      I317333     C111565    Male   21            Shoes         3  1800.51
# 2      I127801     C266599    Male   20         Clothing         1   300.08
# 3      I173702     C988172  Female   66            Shoes         5  3000.85
# 4      I337046     C189076  Female   53            Books         4    60.60
# ..         ...         ...     ...  ...              ...       ...      ...
# 995    I248527     C307014  Female   58            Shoes         1   600.17
# 996    I103907     C280853    Male   56         Clothing         4  1200.32
# 997    I109766     C106066  Female   57  Food & Beverage         5    26.15
# 998    I195981     C257683  Female   38            Shoes         1   600.17
# 999    I583553     C364009  Female   55         Souvenir         3    35.19
#
#     payment_method invoice_date     shopping_mall
# ...

# %%
new_data = pd.read_csv("customer_shopping_data.csv", skiprows = 10 , nrows = 1000  )
new_data
# Out:
#      I326945  C283361  Female  60         Clothing  2  600.16  Credit Card  \
# 0    I306368  C240286  Female  36  Food & Beverage  2   10.46         Cash
# 1    I139207  C191708  Female  29            Books  1   15.15  Credit Card
# 2    I640508  C225330  Female  67             Toys  4  143.36   Debit Card
# 3    I179802  C312861    Male  25         Clothing  2  600.16         Cash
# 4    I336189  C555402  Female  67         Clothing  2  600.16  Credit Card
# ..       ...      ...     ...  ..              ... ..     ...          ...
# 995  I335770  C336888    Male  57        Cosmetics  1   40.66   Debit Card
# 996  I273054  C148034    Male  43  Food & Beverage  5   26.15   Debit Card
# 997  I226742  C724391  Female  56         Clothing  3  900.24         Cash
# 998  I259039  C180485  Female  40         Clothing  1  300.08   Debit Card
# 999  I263787  C323464  Female  60  Food & Beverage  4   20.92         Cash
#
#      22/08/2021             Kanyon
# ...

# %%
data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount       date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00 2022-08-05
# ...

# %%
data.to_csv("WE_Training.csv", index = False)

# %%
updated_data = pd.read_csv("WE_Training.csv")
updated_data
# Out:
#       invoice_no  gender  age         category  quantity    price  \
# 0        I138884  Female   28         Clothing         5  1500.40
# 1        I317333    Male   21            Shoes         3  1800.51
# 2        I127801    Male   20         Clothing         1   300.08
# 3        I173702  Female   66            Shoes         5  3000.85
# 4        I337046  Female   53            Books         4    60.60
# ...          ...     ...  ...              ...       ...      ...
# 99452    I219422  Female   45         Souvenir         5    58.65
# 99453    I325143    Male   27  Food & Beverage         2    10.46
# 99454    I824010    Male   63  Food & Beverage         2    10.46
# 99455    I702964    Male   56       Technology         4  4200.00
# 99456    I232867  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  total_amount        date  \
# 0        Credit Card     5/8/2022            Kanyon       7502.00  2022-08-05
# ...
