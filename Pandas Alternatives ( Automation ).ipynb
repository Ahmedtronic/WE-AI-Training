# %% [markdown]
# <center> <h1> Pandas Alternatives </h1> </center>
# <br>
# Pyspark, Flink , Dask, Mito, Polars, modin, Vaex, YoloPandas, PandasAI, pandas-profiling, vanna, sweetviz, autoviz , auto clean, app the bricks

# %% [markdown]
# ### 1. Pyspark
# Check this : https://sparkbyexamples.com/pyspark-tutorial/

# %% [markdown]
# Also check : https://colab.research.google.com/drive/18oeYUS13jbaQLlADZyKqkQfOzzw6zg1V?authuser=2#scrollTo=VNxSW0hwDlRR

# %% [markdown]
# ### 2. Dask

# %% [markdown]
# check this : https://docs.dask.org/en/stable/dataframe.html
#
# When not to use Dask DataFrames
#
# Dask DataFrames are often used either when …
#
# -    Your data is too big
# -   Your computation is too slow and other techniques don’t work
#
# You should probably stick to just using pandas if …
#
#  -   Your data is small
#  -   Your computation is fast (subsecond)
#  -   There are simpler ways to accelerate your computation, like avoiding .apply or Python for loops and using a built-in pandas method instead.

# %% [markdown]
# ### 3. Mito
# check this : https://github.com/mito-ds/mito <br>
# check this : https://www.trymito.io/ <br>
# check this : https://docs.trymito.io/how-to/interacting-with-your-data/mito-spreadsheet-formulas

# %% [markdown]
# ### 4. Polars
# check this : https://github.com/pola-rs/polars

# %% [markdown]
# ### 5. Modin
# check this: https://github.com/modin-project/modin

# %% [markdown]
# ### 6. Vaex
# check this : https://github.com/vaexio/vaex

# %% [markdown]
# ### 7. YoloPandas :
# check this : https://github.com/ccurme/yolopandas/blob/main/docs/example_notebooks/example.ipynb

# %% [markdown]
# ### 8. PandasAI
# check this : https://github.com/sinaptik-ai/pandas-ai

# %% [markdown]
# ### 9. Vanna
# check this : https://github.com/vanna-ai/vanna

# %% [markdown]
# ### 10. Ydataprofiling ( pandas profiling )
# check this : https://github.com/ydataai/ydata-profiling <br>
# check this : https://colab.research.google.com/github/ydataai/pandas-profiling/blob/master/examples/titanic/titanic_cloud.ipynb

# %% [markdown]
# ### 11. Sweetviz
# check this : https://colab.research.google.com/drive/1JM6nC5HKxdA9KcajHTCNqmIicMVWpwoi?usp=sharing

# %% [markdown]
# ### 12. AutoViz
# check this : https://github.com/AutoViML/AutoViz

# %% [markdown]
# ### 13. App the bricks
# check this : https://app.thebricks.com/
